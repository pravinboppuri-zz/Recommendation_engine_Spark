# %%
from __future__ import print_function

import sys
import itertools
from math import sqrt
from operator import add
from os.path import join, isfile, dirname
from pyspark import SparkContext, SparkConf, SQLContext
from pyspark.mllib.recommendation import ALS, MatrixFactorizationModel, Rating
from pyspark.sql.types import StructType
from pyspark.sql.types import StructField
from pyspark.sql.types import StringType
from pyspark.sql.types import FloatType

# %%
import pandas as pd

# %%
conf = SparkConf().setAppName("app_collaborative")
sc = SparkContext(conf=conf)
sc.setCheckpointDir('checkpoint/')
sqlContext = SQLContext(sc)

# %%
data_cols = ['userid','movieid','rating','timestamp']
item_cols = ['movieid','movietitle','release date',
'video release date','IMDb URL','unknown','Action',
'Adventure','Animation','Childrens','Comedy','Crime',
'Documentary','Drama','Fantasy','Film-Noir','Horror',
'Musical','Mystery','Romance ','Sci-Fi','Thriller',
'War' ,'Western']
user_cols = ['userid','age','gender','occupation',
'zip code']

users = pd.read_csv('/home/bella/ml-100k/u.user', sep='|',
names=user_cols, encoding='latin-1')

item = pd.read_csv('/home/bella/ml-100k/u.item', sep='|',
names=item_cols, encoding='latin-1')
data = pd.read_csv('/home/bella/ml-100k/u.data', sep='\t',
names=data_cols, encoding='latin-1')

dataset = pd.merge(pd.merge(item, data),users)
df = dataset[['userid','movieid','rating']]
dataframe =sqlContext.createDataFrame(df)

# %%
rdd = dataframe.rdd

# %%
rdd.collect()
# Out:
# [Row(userid=308, movieid=1, rating=4),
#  Row(userid=308, movieid=4, rating=5),
#  Row(userid=308, movieid=5, rating=4),
#  Row(userid=308, movieid=7, rating=4),
#  Row(userid=308, movieid=8, rating=5),
#  Row(userid=308, movieid=9, rating=4),
#  Row(userid=308, movieid=11, rating=5),
#  Row(userid=308, movieid=12, rating=5),
#  Row(userid=308, movieid=15, rating=3),
#  Row(userid=308, movieid=17, rating=4),
#  Row(userid=308, movieid=19, rating=3),
#  Row(userid=308, movieid=21, rating=3),
#  Row(userid=308, movieid=22, rating=4),
#  Row(userid=308, movieid=23, rating=5),
#  Row(userid=308, movieid=24, rating=4),
#  Row(userid=308, movieid=25, rating=4),
#  Row(userid=308, movieid=28, rating=3),
#  Row(userid=308, movieid=30, rating=4),
#  Row(userid=308, movieid=31, rating=3),
#  Row(userid=308, movieid=32, rating=5),
#  Row(userid=308, movieid=42, rating=4),
#  Row(userid=308, movieid=44, rating=4),
#  Row(userid=308, movieid=45, rating=4),
#  Row(userid=308, movieid=47, rating=4),
#  Row(userid=308, movieid=48, rating=4),
#  Row(userid=308, movieid=49, rating=3),
#  Row(userid=308, movieid=50, rating=5),
#  Row(userid=308, movieid=54, rating=2),
#  Row(userid=308, movieid=55, rating=3),
#  Row(userid=308, movieid=56, rating=5),
#  Row(userid=308, movieid=58, rating=3),
#  Row(userid=308, movieid=59, rating=4),
#  Row(userid=308, movieid=60, rating=3),
#  Row(userid=308, movieid=61, rating=3),
#  Row(userid=308, movieid=64, rating=4),
#  Row(userid=308, movieid=65, rating=3),
#  Row(userid=308, movieid=66, rating=4),
#  Row(userid=308, movieid=68, rating=4),
#  Row(userid=308, movieid=69, rating=2),
#  Row(userid=308, movieid=70, rating=4),
#  Row(userid=308, movieid=71, rating=4),
#  Row(userid=308, movieid=72, rating=4),
#  Row(userid=308, movieid=73, rating=3),
#  Row(userid=308, movieid=74, rating=4),
#  Row(userid=308, movieid=77, rating=3),
#  Row(userid=308, movieid=79, rating=4),
#  Row(userid=308, movieid=81, rating=5),
#  Row(userid=308, movieid=82, rating=4),
#  Row(userid=308, movieid=85, rating=4),
#  Row(userid=308, movieid=87, rating=4),
#  Row(userid=308, movieid=88, rating=4),
#  Row(userid=308, movieid=89, rating=5),
#  Row(userid=308, movieid=91, rating=4),
#  Row(userid=308, movieid=92, rating=4),
#  Row(userid=308, movieid=95, rating=4),
#  Row(userid=308, movieid=96, rating=4),
#  Row(userid=308, movieid=97, rating=1),
#  Row(userid=308, movieid=98, rating=3),
#  Row(userid=308, movieid=99, rating=4),
#  Row(userid=308, movieid=100, rating=5),
#  Row(userid=308, movieid=107, rating=4),
#  Row(userid=308, movieid=109, rating=3),
#  Row(userid=308, movieid=116, rating=4),
#  Row(userid=308, movieid=117, rating=3),
#  Row(userid=308, movieid=118, rating=3),
#  Row(userid=308, movieid=121, rating=3),
#  Row(userid=308, movieid=122, rating=4),
#  Row(userid=308, movieid=123, rating=3),
#  Row(userid=308, movieid=124, rating=4),
#  Row(userid=308, movieid=127, rating=4),
#  Row(userid=308, movieid=129, rating=5),
#  Row(userid=308, movieid=131, rating=4),
#  Row(userid=308, movieid=132, rating=3),
#  Row(userid=308, movieid=133, rating=3),
#  Row(userid=308, movieid=134, rating=5),
#  Row(userid=308, movieid=135, rating=5),
#  Row(userid=308, movieid=139, rating=3),
#  Row(userid=308, movieid=141, rating=3),
#  Row(userid=308, movieid=143, rating=4),
#  Row(userid=308, movieid=144, rating=3),
#  Row(userid=308, movieid=147, rating=3),
#  Row(userid=308, movieid=148, rating=3),
#  Row(userid=308, movieid=151, rating=4),
#  Row(userid=308, movieid=152, rating=5),
#  Row(userid=308, movieid=153, rating=5),
#  Row(userid=308, movieid=154, rating=4),
#  Row(userid=308, movieid=156, rating=4),
#  Row(userid=308, movieid=157, rating=5),
#  Row(userid=308, movieid=160, rating=4),
#  Row(userid=308, movieid=161, rating=3),
#  Row(userid=308, movieid=162, rating=4),
#  Row(userid=308, movieid=163, rating=4),
#  Row(userid=308, movieid=164, rating=4),
#  Row(userid=308, movieid=165, rating=3),
#  Row(userid=308, movieid=166, rating=3),
#  Row(userid=308, movieid=168, rating=4),
#  Row(userid=308, movieid=169, rating=5),
#  Row(userid=308, movieid=170, rating=3),
#  Row(userid=308, movieid=171, rating=4),
#  Row(userid=308, movieid=172, rating=4),
#  Row(userid=308, movieid=174, rating=4),
#  Row(userid=308, movieid=175, rating=5),
#  Row(userid=308, movieid=176, rating=4),
#  Row(userid=308, movieid=177, rating=5),
#  Row(userid=308, movieid=178, rating=4),
#  Row(userid=308, movieid=179, rating=4),
#  Row(userid=308, movieid=180, rating=5),
#  Row(userid=308, movieid=181, rating=4),
#  Row(userid=308, movieid=182, rating=5),
#  Row(userid=308, movieid=183, rating=4),
#  Row(userid=308, movieid=184, rating=4),
#  Row(userid=308, movieid=185, rating=4),
#  Row(userid=308, movieid=186, rating=4),
#  Row(userid=308, movieid=187, rating=5),
#  Row(userid=308, movieid=191, rating=4),
#  Row(userid=308, movieid=192, rating=5),
#  Row(userid=308, movieid=193, rating=3),
#  Row(userid=308, movieid=194, rating=5),
#  Row(userid=308, movieid=195, rating=5),
#  Row(userid=308, movieid=196, rating=3),
#  Row(userid=308, movieid=197, rating=3),
#  Row(userid=308, movieid=198, rating=3),
#  Row(userid=308, movieid=199, rating=4),
#  Row(userid=308, movieid=200, rating=5),
#  Row(userid=308, movieid=201, rating=5),
#  Row(userid=308, movieid=202, rating=4),
#  Row(userid=308, movieid=203, rating=5),
#  Row(userid=308, movieid=204, rating=4),
#  Row(userid=308, movieid=205, rating=3),
#  Row(userid=308, movieid=208, rating=4),
#  Row(userid=308, movieid=209, rating=4),
#  Row(userid=308, movieid=210, rating=4),
#  Row(userid=308, movieid=211, rating=4),
#  Row(userid=308, movieid=213, rating=4),
#  Row(userid=308, movieid=214, rating=2),
#  Row(userid=308, movieid=215, rating=3),
#  Row(userid=308, movieid=216, rating=3),
#  Row(userid=308, movieid=218, rating=5),
#  Row(userid=308, movieid=219, rating=3),
#  Row(userid=308, movieid=223, rating=4),
#  Row(userid=308, movieid=226, rating=3),
#  Row(userid=308, movieid=230, rating=4),
#  Row(userid=308, movieid=231, rating=3),
#  Row(userid=308, movieid=233, rating=3),
#  Row(userid=308, movieid=234, rating=3),
#  Row(userid=308, movieid=235, rating=3),
#  Row(userid=308, movieid=237, rating=3),
#  Row(userid=308, movieid=238, rating=5),
#  Row(userid=308, movieid=239, rating=3),
#  Row(userid=308, movieid=241, rating=4),
#  Row(userid=308, movieid=248, rating=4),
#  Row(userid=308, movieid=254, rating=2),
#  Row(userid=308, movieid=255, rating=4),
#  Row(userid=308, movieid=257, rating=4),
#  Row(userid=308, movieid=259, rating=3),
#  Row(userid=308, movieid=264, rating=2),
#  Row(userid=308, movieid=265, rating=3),
#  Row(userid=308, movieid=273, rating=2),
#  Row(userid=308, movieid=274, rating=3),
#  Row(userid=308, movieid=275, rating=4),
#  Row(userid=308, movieid=276, rating=4),
#  Row(userid=308, movieid=283, rating=3),
#  Row(userid=308, movieid=284, rating=4),
#  Row(userid=308, movieid=285, rating=5),
#  Row(userid=308, movieid=288, rating=4),
#  Row(userid=308, movieid=291, rating=3),
#  Row(userid=308, movieid=293, rating=4),
#  Row(userid=308, movieid=294, rating=3),
#  Row(userid=308, movieid=295, rating=3),
#  Row(userid=308, movieid=298, rating=5),
#  Row(userid=308, movieid=309, rating=1),
#  Row(userid=308, movieid=313, rating=3),
#  Row(userid=308, movieid=318, rating=4),
#  Row(userid=308, movieid=319, rating=4),
#  Row(userid=308, movieid=321, rating=3),
#  Row(userid=308, movieid=322, rating=2),
#  Row(userid=308, movieid=356, rating=3),
#  Row(userid=308, movieid=357, rating=4),
#  Row(userid=308, movieid=365, rating=3),
#  Row(userid=308, movieid=367, rating=4),
#  Row(userid=308, movieid=371, rating=3),
#  Row(userid=308, movieid=378, rating=3),
#  Row(userid=308, movieid=382, rating=4),
#  Row(userid=308, movieid=385, rating=4),
#  Row(userid=308, movieid=392, rating=4),
#  Row(userid=308, movieid=393, rating=4),
#  Row(userid=308, movieid=396, rating=4),
#  Row(userid=308, movieid=402, rating=4),
#  Row(userid=308, movieid=403, rating=4),
#  Row(userid=308, movieid=404, rating=3),
#  Row(userid=308, movieid=408, rating=5),
#  Row(userid=308, movieid=410, rating=4),
#  Row(userid=308, movieid=411, rating=4),
#  Row(userid=308, movieid=417, rating=3),
#  Row(userid=308, movieid=419, rating=4),
#  Row(userid=308, movieid=420, rating=4),
#  Row(userid=308, movieid=423, rating=5),
#  Row(userid=308, movieid=425, rating=4),
#  Row(userid=308, movieid=427, rating=4),
#  Row(userid=308, movieid=428, rating=5),
#  Row(userid=308, movieid=429, rating=4),
#  Row(userid=308, movieid=430, rating=4),
#  Row(userid=308, movieid=432, rating=4),
#  Row(userid=308, movieid=433, rating=5),
#  Row(userid=308, movieid=434, rating=4),
#  Row(userid=308, movieid=435, rating=4),
#  Row(userid=308, movieid=436, rating=4),
#  Row(userid=308, movieid=443, rating=3),
#  Row(userid=308, movieid=447, rating=4),
#  Row(userid=308, movieid=448, rating=3),
#  Row(userid=308, movieid=449, rating=3),
#  Row(userid=308, movieid=452, rating=2),
#  Row(userid=308, movieid=455, rating=4),
#  Row(userid=308, movieid=461, rating=4),
#  Row(userid=308, movieid=463, rating=4),
#  Row(userid=308, movieid=466, rating=5),
#  Row(userid=308, movieid=467, rating=4),
#  Row(userid=308, movieid=469, rating=5),
#  Row(userid=308, movieid=471, rating=3),
#  Row(userid=308, movieid=472, rating=2),
#  Row(userid=308, movieid=473, rating=3),
#  Row(userid=308, movieid=475, rating=4),
#  Row(userid=308, movieid=477, rating=4),
#  Row(userid=308, movieid=479, rating=5),
#  Row(userid=308, movieid=480, rating=4),
#  Row(userid=308, movieid=481, rating=4),
#  Row(userid=308, movieid=482, rating=5),
#  Row(userid=308, movieid=483, rating=3),
#  Row(userid=308, movieid=484, rating=3),
#  Row(userid=308, movieid=485, rating=3),
#  Row(userid=308, movieid=486, rating=4),
#  Row(userid=308, movieid=487, rating=4),
#  Row(userid=308, movieid=488, rating=4),
#  Row(userid=308, movieid=490, rating=4),
#  Row(userid=308, movieid=492, rating=3),
#  Row(userid=308, movieid=493, rating=3),
#  Row(userid=308, movieid=494, rating=5),
#  Row(userid=308, movieid=495, rating=3),
#  Row(userid=308, movieid=496, rating=3),
#  Row(userid=308, movieid=498, rating=5),
#  Row(userid=308, movieid=499, rating=3),
#  Row(userid=308, movieid=501, rating=4),
#  Row(userid=308, movieid=502, rating=5),
#  Row(userid=308, movieid=504, rating=4),
#  Row(userid=308, movieid=505, rating=3),
#  Row(userid=308, movieid=506, rating=4),
#  Row(userid=308, movieid=507, rating=3),
#  Row(userid=308, movieid=509, rating=4),
#  Row(userid=308, movieid=510, rating=3),
#  Row(userid=308, movieid=511, rating=5),
#  Row(userid=308, movieid=512, rating=5),
#  Row(userid=308, movieid=513, rating=3),
#  Row(userid=308, movieid=514, rating=4),
#  Row(userid=308, movieid=515, rating=3),
#  Row(userid=308, movieid=516, rating=4),
#  Row(userid=308, movieid=517, rating=4),
#  Row(userid=308, movieid=519, rating=4),
#  Row(userid=308, movieid=520, rating=4),
#  Row(userid=308, movieid=521, rating=3),
#  Row(userid=308, movieid=522, rating=3),
#  Row(userid=308, movieid=523, rating=4),
#  Row(userid=308, movieid=525, rating=5),
#  Row(userid=308, movieid=526, rating=3),
#  Row(userid=308, movieid=528, rating=3),
#  Row(userid=308, movieid=530, rating=4),
#  Row(userid=308, movieid=531, rating=4),
#  Row(userid=308, movieid=537, rating=4),
#  Row(userid=308, movieid=546, rating=3),
#  Row(userid=308, movieid=550, rating=4),
#  Row(userid=308, movieid=558, rating=4),
#  Row(userid=308, movieid=559, rating=4),
#  Row(userid=308, movieid=566, rating=4),
#  Row(userid=308, movieid=567, rating=4),
#  Row(userid=308, movieid=568, rating=5),
#  Row(userid=308, movieid=569, rating=3),
#  Row(userid=308, movieid=578, rating=2),
#  Row(userid=308, movieid=579, rating=3),
#  Row(userid=308, movieid=581, rating=4),
#  Row(userid=308, movieid=582, rating=3),
#  Row(userid=308, movieid=583, rating=4),
#  Row(userid=308, movieid=584, rating=4),
#  Row(userid=308, movieid=588, rating=5),
#  Row(userid=308, movieid=589, rating=4),
#  Row(userid=308, movieid=591, rating=3),
#  Row(userid=308, movieid=597, rating=3),
#  Row(userid=308, movieid=602, rating=4),
#  Row(userid=308, movieid=603, rating=5),
#  Row(userid=308, movieid=605, rating=4),
#  Row(userid=308, movieid=607, rating=3),
#  Row(userid=308, movieid=609, rating=4),
#  Row(userid=308, movieid=610, rating=4),
#  Row(userid=308, movieid=611, rating=4),
#  Row(userid=308, movieid=613, rating=4),
#  Row(userid=308, movieid=614, rating=3),
#  Row(userid=308, movieid=615, rating=3),
#  Row(userid=308, movieid=616, rating=2),
#  Row(userid=308, movieid=618, rating=4),
#  Row(userid=308, movieid=628, rating=3),
#  Row(userid=308, movieid=629, rating=4),
#  Row(userid=308, movieid=632, rating=3),
#  Row(userid=308, movieid=633, rating=4),
#  Row(userid=308, movieid=634, rating=4),
#  Row(userid=308, movieid=637, rating=3),
#  Row(userid=308, movieid=640, rating=4),
#  Row(userid=308, movieid=641, rating=4),
#  Row(userid=308, movieid=642, rating=5),
#  Row(userid=308, movieid=646, rating=5),
#  Row(userid=308, movieid=648, rating=4),
#  Row(userid=308, movieid=649, rating=4),
#  Row(userid=308, movieid=653, rating=5),
#  Row(userid=308, movieid=654, rating=5),
#  Row(userid=308, movieid=655, rating=4),
#  Row(userid=308, movieid=656, rating=3),
#  Row(userid=308, movieid=657, rating=4),
#  Row(userid=308, movieid=659, rating=3),
#  Row(userid=308, movieid=660, rating=3),
#  Row(userid=308, movieid=661, rating=4),
#  Row(userid=308, movieid=663, rating=5),
#  Row(userid=308, movieid=664, rating=5),
#  Row(userid=308, movieid=665, rating=4),
#  Row(userid=308, movieid=671, rating=4),
#  Row(userid=308, movieid=673, rating=4),
#  Row(userid=308, movieid=675, rating=4),
#  Row(userid=308, movieid=678, rating=3),
#  Row(userid=308, movieid=679, rating=4),
#  Row(userid=308, movieid=684, rating=3),
#  Row(userid=308, movieid=686, rating=4),
#  Row(userid=308, movieid=692, rating=3),
#  Row(userid=308, movieid=693, rating=3),
#  Row(userid=308, movieid=699, rating=4),
#  Row(userid=308, movieid=705, rating=5),
#  Row(userid=308, movieid=708, rating=4),
#  Row(userid=308, movieid=709, rating=3),
#  Row(userid=308, movieid=712, rating=4),
#  Row(userid=308, movieid=715, rating=5),
#  Row(userid=308, movieid=729, rating=3),
#  Row(userid=308, movieid=732, rating=4),
#  Row(userid=308, movieid=736, rating=3),
#  Row(userid=308, movieid=739, rating=4),
#  Row(userid=308, movieid=741, rating=4),
#  Row(userid=308, movieid=742, rating=4),
#  Row(userid=308, movieid=746, rating=4),
#  Row(userid=308, movieid=747, rating=3),
#  Row(userid=308, movieid=755, rating=3),
#  Row(userid=308, movieid=770, rating=4),
#  Row(userid=308, movieid=778, rating=3),
#  Row(userid=308, movieid=792, rating=3),
#  Row(userid=308, movieid=802, rating=3),
#  Row(userid=308, movieid=805, rating=4),
#  Row(userid=308, movieid=806, rating=4),
#  Row(userid=308, movieid=811, rating=4),
#  Row(userid=308, movieid=822, rating=4),
#  Row(userid=308, movieid=824, rating=3),
#  Row(userid=308, movieid=825, rating=4),
#  Row(userid=308, movieid=826, rating=3),
#  Row(userid=308, movieid=842, rating=3),
#  Row(userid=308, movieid=843, rating=3),
#  Row(userid=308, movieid=848, rating=4),
#  Row(userid=308, movieid=853, rating=5),
#  Row(userid=308, movieid=856, rating=4),
#  Row(userid=308, movieid=863, rating=3),
#  Row(userid=308, movieid=921, rating=4),
#  Row(userid=308, movieid=928, rating=4),
#  Row(userid=308, movieid=942, rating=3),
#  Row(userid=308, movieid=945, rating=4),
#  Row(userid=308, movieid=959, rating=3),
#  Row(userid=308, movieid=962, rating=4),
#  Row(userid=308, movieid=965, rating=4),
#  Row(userid=308, movieid=966, rating=3),
#  Row(userid=308, movieid=968, rating=4),
#  Row(userid=308, movieid=1006, rating=4),
#  Row(userid=308, movieid=1019, rating=4),
#  Row(userid=308, movieid=1021, rating=4),
#  Row(userid=308, movieid=1028, rating=2),
#  Row(userid=308, movieid=1045, rating=4),
#  Row(userid=308, movieid=1046, rating=4),
#  Row(userid=308, movieid=1047, rating=3),
#  Row(userid=308, movieid=1065, rating=5),
#  Row(userid=308, movieid=1073, rating=3),
#  Row(userid=308, movieid=1074, rating=3),
#  Row(userid=308, movieid=1118, rating=4),
#  Row(userid=308, movieid=1121, rating=3),
#  Row(userid=308, movieid=1126, rating=3),
#  Row(userid=308, movieid=1135, rating=4),
#  Row(userid=308, movieid=1140, rating=4),
#  Row(userid=308, movieid=1147, rating=4),
#  Row(userid=308, movieid=1154, rating=2),
#  Row(userid=308, movieid=1169, rating=5),
#  Row(userid=308, movieid=1197, rating=4),
#  Row(userid=308, movieid=1211, rating=3),
#  Row(userid=308, movieid=1252, rating=3),
#  Row(userid=308, movieid=1286, rating=3),
#  Row(userid=308, movieid=1404, rating=4),
#  Row(userid=308, movieid=1411, rating=4),
#  Row(userid=308, movieid=1421, rating=4),
#  Row(userid=308, movieid=1456, rating=4),
#  Row(userid=308, movieid=1515, rating=4),
#  Row(userid=287, movieid=1, rating=5),
#  Row(userid=287, movieid=4, rating=4),
#  Row(userid=287, movieid=9, rating=5),
#  Row(userid=287, movieid=11, rating=5),
#  Row(userid=287, movieid=28, rating=5),
#  Row(userid=287, movieid=39, rating=5),
#  Row(userid=287, movieid=50, rating=5),
#  Row(userid=287, movieid=56, rating=5),
#  Row(userid=287, movieid=64, rating=5),
#  Row(userid=287, movieid=92, rating=4),
#  Row(userid=287, movieid=98, rating=4),
#  Row(userid=287, movieid=100, rating=5),
#  Row(userid=287, movieid=108, rating=4),
#  Row(userid=287, movieid=111, rating=3),
#  Row(userid=287, movieid=117, rating=5),
#  Row(userid=287, movieid=121, rating=4),
#  Row(userid=287, movieid=156, rating=5),
#  Row(userid=287, movieid=168, rating=5),
#  Row(userid=287, movieid=181, rating=3),
#  Row(userid=287, movieid=200, rating=4),
#  Row(userid=287, movieid=201, rating=5),
#  Row(userid=287, movieid=208, rating=4),
#  Row(userid=287, movieid=218, rating=5),
#  Row(userid=287, movieid=222, rating=5),
#  Row(userid=287, movieid=235, rating=4),
#  Row(userid=287, movieid=237, rating=5),
#  Row(userid=287, movieid=240, rating=2),
#  Row(userid=287, movieid=246, rating=4),
#  Row(userid=287, movieid=248, rating=5),
#  Row(userid=287, movieid=249, rating=5),
#  Row(userid=287, movieid=250, rating=3),
#  Row(userid=287, movieid=252, rating=1),
#  Row(userid=287, movieid=257, rating=4),
#  Row(userid=287, movieid=268, rating=4),
#  Row(userid=287, movieid=276, rating=4),
#  Row(userid=287, movieid=291, rating=5),
#  Row(userid=287, movieid=294, rating=5),
#  Row(userid=287, movieid=298, rating=4),
#  Row(userid=287, movieid=301, rating=3),
#  Row(userid=287, movieid=313, rating=4),
#  Row(userid=287, movieid=327, rating=5),
#  Row(userid=287, movieid=340, rating=5),
#  Row(userid=287, movieid=346, rating=5),
#  Row(userid=287, movieid=347, rating=4),
#  Row(userid=287, movieid=426, rating=3),
#  Row(userid=287, movieid=461, rating=5),
#  Row(userid=287, movieid=476, rating=1),
#  Row(userid=287, movieid=546, rating=4),
#  Row(userid=287, movieid=591, rating=5),
#  Row(userid=287, movieid=652, rating=4),
#  Row(userid=287, movieid=682, rating=4),
#  Row(userid=287, movieid=710, rating=4),
#  Row(userid=287, movieid=742, rating=3),
#  Row(userid=287, movieid=748, rating=4),
#  Row(userid=287, movieid=815, rating=3),
#  Row(userid=287, movieid=845, rating=5),
#  Row(userid=287, movieid=895, rating=2),
#  Row(userid=287, movieid=926, rating=4),
#  Row(userid=287, movieid=941, rating=3),
#  Row(userid=287, movieid=952, rating=4),
#  Row(userid=287, movieid=1016, rating=5),
#  Row(userid=287, movieid=1067, rating=2),
#  Row(userid=148, movieid=1, rating=4),
#  Row(userid=148, movieid=7, rating=5),
#  Row(userid=148, movieid=8, rating=4),
#  Row(userid=148, movieid=50, rating=5),
#  Row(userid=148, movieid=56, rating=5),
#  Row(userid=148, movieid=69, rating=5),
#  Row(userid=148, movieid=70, rating=5),
#  Row(userid=148, movieid=71, rating=5),
#  Row(userid=148, movieid=78, rating=1),
#  Row(userid=148, movieid=89, rating=5),
#  Row(userid=148, movieid=98, rating=3),
#  Row(userid=148, movieid=114, rating=5),
#  Row(userid=148, movieid=116, rating=5),
#  Row(userid=148, movieid=127, rating=1),
#  Row(userid=148, movieid=132, rating=4),
#  Row(userid=148, movieid=133, rating=5),
#  Row(userid=148, movieid=135, rating=5),
#  Row(userid=148, movieid=140, rating=1),
#  Row(userid=148, movieid=151, rating=4),
#  Row(userid=148, movieid=163, rating=4),
#  Row(userid=148, movieid=164, rating=4),
#  Row(userid=148, movieid=168, rating=5),
#  Row(userid=148, movieid=169, rating=5),
#  Row(userid=148, movieid=172, rating=5),
#  Row(userid=148, movieid=173, rating=5),
#  Row(userid=148, movieid=174, rating=5),
#  Row(userid=148, movieid=175, rating=4),
#  Row(userid=148, movieid=177, rating=2),
#  Row(userid=148, movieid=181, rating=5),
#  Row(userid=148, movieid=185, rating=1),
#  Row(userid=148, movieid=189, rating=4),
#  Row(userid=148, movieid=190, rating=2),
#  Row(userid=148, movieid=191, rating=1),
#  Row(userid=148, movieid=194, rating=5),
#  Row(userid=148, movieid=204, rating=3),
#  Row(userid=148, movieid=209, rating=5),
#  Row(userid=148, movieid=214, rating=5),
#  Row(userid=148, movieid=222, rating=4),
#  Row(userid=148, movieid=227, rating=4),
#  Row(userid=148, movieid=228, rating=4),
#  Row(userid=148, movieid=234, rating=3),
#  Row(userid=148, movieid=238, rating=4),
#  Row(userid=148, movieid=357, rating=5),
#  Row(userid=148, movieid=408, rating=5),
#  Row(userid=148, movieid=418, rating=3),
#  Row(userid=148, movieid=432, rating=5),
#  Row(userid=148, movieid=473, rating=5),
#  Row(userid=148, movieid=474, rating=5),
#  Row(userid=148, movieid=495, rating=4),
#  Row(userid=148, movieid=496, rating=3),
#  Row(userid=148, movieid=501, rating=4),
#  Row(userid=148, movieid=507, rating=5),
#  Row(userid=148, movieid=509, rating=5),
#  Row(userid=148, movieid=521, rating=1),
#  Row(userid=148, movieid=529, rating=5),
#  Row(userid=148, movieid=549, rating=3),
#  Row(userid=148, movieid=588, rating=4),
#  Row(userid=148, movieid=596, rating=5),
#  Row(userid=148, movieid=663, rating=5),
#  Row(userid=148, movieid=713, rating=3),
#  Row(userid=148, movieid=969, rating=4),
#  Row(userid=148, movieid=993, rating=4),
#  Row(userid=148, movieid=1012, rating=4),
#  Row(userid=148, movieid=1039, rating=2),
#  Row(userid=148, movieid=1149, rating=5),
#  Row(userid=280, movieid=1, rating=4),
#  Row(userid=280, movieid=2, rating=3),
#  Row(userid=280, movieid=3, rating=2),
#  Row(userid=280, movieid=4, rating=3),
#  Row(userid=280, movieid=5, rating=4),
#  Row(userid=280, movieid=7, rating=4),
#  Row(userid=280, movieid=8, rating=5),
#  Row(userid=280, movieid=9, rating=5),
#  Row(userid=280, movieid=11, rating=5),
#  Row(userid=280, movieid=12, rating=5),
#  Row(userid=280, movieid=13, rating=5),
#  Row(userid=280, movieid=22, rating=5),
#  Row(userid=280, movieid=29, rating=3),
#  Row(userid=280, movieid=31, rating=4),
#  Row(userid=280, movieid=33, rating=3),
#  Row(userid=280, movieid=38, rating=3),
#  Row(userid=280, movieid=40, rating=5),
#  Row(userid=280, movieid=50, rating=3),
#  Row(userid=280, movieid=53, rating=5),
#  Row(userid=280, movieid=54, rating=2),
#  Row(userid=280, movieid=56, rating=5),
#  Row(userid=280, movieid=58, rating=4),
#  Row(userid=280, movieid=62, rating=3),
#  Row(userid=280, movieid=66, rating=5),
#  Row(userid=280, movieid=67, rating=4),
#  Row(userid=280, movieid=68, rating=3),
#  Row(userid=280, movieid=69, rating=4),
#  Row(userid=280, movieid=70, rating=4),
#  Row(userid=280, movieid=71, rating=4),
#  Row(userid=280, movieid=72, rating=4),
#  Row(userid=280, movieid=73, rating=3),
#  Row(userid=280, movieid=76, rating=2),
#  Row(userid=280, movieid=77, rating=3),
#  Row(userid=280, movieid=79, rating=4),
#  Row(userid=280, movieid=80, rating=3),
#  Row(userid=280, movieid=82, rating=2),
#  Row(userid=280, movieid=86, rating=4),
#  Row(userid=280, movieid=88, rating=3),
#  Row(userid=280, movieid=90, rating=4),
#  Row(userid=280, movieid=92, rating=3),
#  Row(userid=280, movieid=94, rating=2),
#  Row(userid=280, movieid=95, rating=5),
#  Row(userid=280, movieid=96, rating=4),
#  Row(userid=280, movieid=98, rating=5),
#  Row(userid=280, movieid=99, rating=2),
#  Row(userid=280, movieid=100, rating=3),
#  Row(userid=280, movieid=102, rating=5),
#  Row(userid=280, movieid=103, rating=3),
#  Row(userid=280, movieid=111, rating=4),
#  Row(userid=280, movieid=112, rating=3),
#  Row(userid=280, movieid=117, rating=5),
#  Row(userid=280, movieid=118, rating=2),
#  Row(userid=280, movieid=125, rating=2),
#  Row(userid=280, movieid=126, rating=3),
#  Row(userid=280, movieid=127, rating=5),
#  Row(userid=280, movieid=128, rating=3),
#  Row(userid=280, movieid=132, rating=4),
#  Row(userid=280, movieid=135, rating=4),
#  Row(userid=280, movieid=140, rating=4),
#  Row(userid=280, movieid=142, rating=4),
#  Row(userid=280, movieid=144, rating=2),
#  Row(userid=280, movieid=145, rating=3),
#  Row(userid=280, movieid=153, rating=5),
#  Row(userid=280, movieid=155, rating=5),
#  Row(userid=280, movieid=156, rating=4),
#  Row(userid=280, movieid=157, rating=3),
#  Row(userid=280, movieid=158, rating=2),
#  Row(userid=280, movieid=159, rating=4),
#  Row(userid=280, movieid=161, rating=4),
#  Row(userid=280, movieid=162, rating=3),
#  Row(userid=280, movieid=167, rating=4),
#  Row(userid=280, movieid=172, rating=3),
#  Row(userid=280, movieid=173, rating=3),
#  Row(userid=280, movieid=174, rating=3),
#  Row(userid=280, movieid=176, rating=3),
#  Row(userid=280, movieid=180, rating=4),
#  Row(userid=280, movieid=181, rating=3),
#  Row(userid=280, movieid=182, rating=3),
#  Row(userid=280, movieid=183, rating=3),
#  Row(userid=280, movieid=195, rating=3),
#  Row(userid=280, movieid=197, rating=2),
#  Row(userid=280, movieid=200, rating=5),
#  Row(userid=280, movieid=202, rating=3),
#  Row(userid=280, movieid=203, rating=4),
#  Row(userid=280, movieid=204, rating=3),
#  Row(userid=280, movieid=210, rating=2),
#  Row(userid=280, movieid=215, rating=3),
#  Row(userid=280, movieid=216, rating=5),
#  Row(userid=280, movieid=217, rating=3),
#  Row(userid=280, movieid=218, rating=4),
#  Row(userid=280, movieid=219, rating=2),
#  Row(userid=280, movieid=220, rating=5),
#  Row(userid=280, movieid=222, rating=3),
#  Row(userid=280, movieid=225, rating=4),
#  Row(userid=280, movieid=226, rating=3),
#  Row(userid=280, movieid=227, rating=3),
#  Row(userid=280, movieid=228, rating=3),
#  Row(userid=280, movieid=229, rating=3),
#  Row(userid=280, movieid=230, rating=3),
#  Row(userid=280, movieid=231, rating=3),
#  Row(userid=280, movieid=232, rating=3),
#  Row(userid=280, movieid=233, rating=4),
#  Row(userid=280, movieid=234, rating=3),
#  Row(userid=280, movieid=235, rating=5),
#  Row(userid=280, movieid=237, rating=3),
#  Row(userid=280, movieid=239, rating=3),
#  Row(userid=280, movieid=241, rating=2),
#  Row(userid=280, movieid=245, rating=3),
#  Row(userid=280, movieid=265, rating=4),
#  Row(userid=280, movieid=274, rating=5),
#  Row(userid=280, movieid=276, rating=5),
#  Row(userid=280, movieid=282, rating=3),
#  Row(userid=280, movieid=284, rating=3),
#  Row(userid=280, movieid=286, rating=4),
#  Row(userid=280, movieid=288, rating=5),
#  Row(userid=280, movieid=294, rating=2),
#  Row(userid=280, movieid=313, rating=3),
#  Row(userid=280, movieid=315, rating=5),
#  Row(userid=280, movieid=316, rating=5),
#  Row(userid=280, movieid=318, rating=5),
#  Row(userid=280, movieid=322, rating=4),
#  Row(userid=280, movieid=323, rating=2),
#  Row(userid=280, movieid=324, rating=5),
#  Row(userid=280, movieid=364, rating=3),
#  Row(userid=280, movieid=367, rating=5),
#  Row(userid=280, movieid=379, rating=5),
#  Row(userid=280, movieid=380, rating=2),
#  Row(userid=280, movieid=381, rating=3),
#  Row(userid=280, movieid=384, rating=4),
#  Row(userid=280, movieid=385, rating=5),
#  Row(userid=280, movieid=387, rating=4),
#  Row(userid=280, movieid=388, rating=2),
#  Row(userid=280, movieid=389, rating=5),
#  Row(userid=280, movieid=392, rating=5),
#  Row(userid=280, movieid=393, rating=4),
#  Row(userid=280, movieid=402, rating=4),
#  Row(userid=280, movieid=403, rating=3),
#  Row(userid=280, movieid=404, rating=3),
#  Row(userid=280, movieid=405, rating=2),
#  Row(userid=280, movieid=409, rating=3),
#  Row(userid=280, movieid=411, rating=3),
#  Row(userid=280, movieid=416, rating=5),
#  Row(userid=280, movieid=419, rating=3),
#  Row(userid=280, movieid=420, rating=3),
#  Row(userid=280, movieid=423, rating=5),
#  Row(userid=280, movieid=431, rating=4),
#  Row(userid=280, movieid=448, rating=3),
#  Row(userid=280, movieid=449, rating=3),
#  Row(userid=280, movieid=451, rating=5),
#  Row(userid=280, movieid=452, rating=2),
#  Row(userid=280, movieid=465, rating=3),
#  Row(userid=280, movieid=468, rating=4),
#  Row(userid=280, movieid=471, rating=3),
#  Row(userid=280, movieid=472, rating=2),
#  Row(userid=280, movieid=476, rating=5),
#  Row(userid=280, movieid=483, rating=4),
#  Row(userid=280, movieid=486, rating=5),
#  Row(userid=280, movieid=496, rating=5),
#  Row(userid=280, movieid=499, rating=4),
#  Row(userid=280, movieid=507, rating=3),
#  Row(userid=280, movieid=508, rating=3),
#  Row(userid=280, movieid=527, rating=5),
#  Row(userid=280, movieid=528, rating=3),
#  Row(userid=280, movieid=538, rating=5),
#  Row(userid=280, movieid=540, rating=3),
#  Row(userid=280, movieid=542, rating=3),
#  Row(userid=280, movieid=544, rating=4),
#  Row(userid=280, movieid=546, rating=4),
#  Row(userid=280, movieid=550, rating=2),
#  Row(userid=280, movieid=554, rating=1),
#  Row(userid=280, movieid=559, rating=3),
#  Row(userid=280, movieid=566, rating=4),
#  Row(userid=280, movieid=568, rating=2),
#  Row(userid=280, movieid=571, rating=3),
#  Row(userid=280, movieid=575, rating=2),
#  Row(userid=280, movieid=576, rating=3),
#  Row(userid=280, movieid=584, rating=4),
#  Row(userid=280, movieid=585, rating=3),
#  Row(userid=280, movieid=586, rating=4),
#  Row(userid=280, movieid=588, rating=5),
#  Row(userid=280, movieid=595, rating=3),
#  Row(userid=280, movieid=609, rating=4),
#  Row(userid=280, movieid=619, rating=4),
#  Row(userid=280, movieid=629, rating=4),
#  Row(userid=280, movieid=631, rating=5),
#  Row(userid=280, movieid=655, rating=3),
#  Row(userid=280, movieid=660, rating=5),
#  Row(userid=280, movieid=663, rating=4),
#  Row(userid=280, movieid=670, rating=2),
#  Row(userid=280, movieid=673, rating=4),
#  Row(userid=280, movieid=678, rating=2),
#  Row(userid=280, movieid=690, rating=2),
#  Row(userid=280, movieid=692, rating=3),
#  Row(userid=280, movieid=693, rating=3),
#  Row(userid=280, movieid=697, rating=5),
#  Row(userid=280, movieid=699, rating=4),
#  Row(userid=280, movieid=715, rating=2),
#  Row(userid=280, movieid=722, rating=3),
#  Row(userid=280, movieid=723, rating=5),
#  Row(userid=280, movieid=725, rating=3),
#  Row(userid=280, movieid=728, rating=3),
#  Row(userid=280, movieid=729, rating=2),
#  Row(userid=280, movieid=731, rating=3),
#  Row(userid=280, movieid=735, rating=2),
#  Row(userid=280, movieid=736, rating=2),
#  Row(userid=280, movieid=739, rating=3),
#  Row(userid=280, movieid=742, rating=4),
#  Row(userid=280, movieid=746, rating=4),
#  Row(userid=280, movieid=748, rating=2),
#  Row(userid=280, movieid=750, rating=5),
#  Row(userid=280, movieid=751, rating=3),
#  Row(userid=280, movieid=755, rating=2),
#  Row(userid=280, movieid=756, rating=4),
#  Row(userid=280, movieid=764, rating=4),
#  Row(userid=280, movieid=765, rating=4),
#  Row(userid=280, movieid=769, rating=3),
#  Row(userid=280, movieid=771, rating=3),
#  Row(userid=280, movieid=780, rating=4),
#  Row(userid=280, movieid=781, rating=4),
#  Row(userid=280, movieid=790, rating=4),
#  Row(userid=280, movieid=845, rating=3),
#  Row(userid=280, movieid=866, rating=3),
#  Row(userid=280, movieid=925, rating=4),
#  Row(userid=280, movieid=928, rating=5),
#  Row(userid=280, movieid=934, rating=2),
#  Row(userid=280, movieid=942, rating=5),
#  Row(userid=280, movieid=946, rating=4),
#  Row(userid=280, movieid=975, rating=4),
#  Row(userid=280, movieid=977, rating=3),
#  Row(userid=280, movieid=1015, rating=3),
#  Row(userid=280, movieid=1028, rating=5),
#  Row(userid=280, movieid=1035, rating=4),
#  Row(userid=280, movieid=1041, rating=5),
#  Row(userid=280, movieid=1047, rating=3),
#  Row(userid=280, movieid=1048, rating=4),
#  Row(userid=280, movieid=1049, rating=2),
#  Row(userid=280, movieid=1051, rating=4),
#  Row(userid=280, movieid=1060, rating=3),
#  Row(userid=280, movieid=1063, rating=3),
#  Row(userid=280, movieid=1066, rating=4),
#  Row(userid=280, movieid=1099, rating=5),
#  Row(userid=280, movieid=1112, rating=4),
#  Row(userid=280, movieid=1114, rating=4),
#  Row(userid=280, movieid=1133, rating=3),
#  Row(userid=280, movieid=1168, rating=5),
#  Row(userid=280, movieid=1181, rating=2),
#  Row(userid=280, movieid=1182, rating=3),
#  Row(userid=280, movieid=1207, rating=4),
#  Row(userid=280, movieid=1217, rating=5),
#  Row(userid=280, movieid=1221, rating=5),
#  Row(userid=280, movieid=1297, rating=4),
#  Row(userid=280, movieid=1313, rating=5),
#  Row(userid=280, movieid=1401, rating=5),
#  Row(userid=280, movieid=1459, rating=4),
#  Row(userid=280, movieid=1466, rating=5),
#  Row(userid=280, movieid=1473, rating=3),
#  Row(userid=280, movieid=1478, rating=4),
#  Row(userid=280, movieid=1479, rating=3),
#  Row(userid=66, movieid=1, rating=3),
#  Row(userid=66, movieid=7, rating=3),
#  Row(userid=66, movieid=9, rating=4),
#  Row(userid=66, movieid=15, rating=3),
#  Row(userid=66, movieid=21, rating=1),
#  Row(userid=66, movieid=24, rating=3),
#  Row(userid=66, movieid=50, rating=5),
#  Row(userid=66, movieid=117, rating=3),
#  Row(userid=66, movieid=121, rating=3),
#  Row(userid=66, movieid=127, rating=4),
#  Row(userid=66, movieid=181, rating=5),
#  Row(userid=66, movieid=237, rating=4),
#  Row(userid=66, movieid=248, rating=4),
#  Row(userid=66, movieid=249, rating=4),
#  Row(userid=66, movieid=257, rating=3),
#  Row(userid=66, movieid=258, rating=4),
#  Row(userid=66, movieid=280, rating=4),
#  Row(userid=66, movieid=281, rating=4),
#  Row(userid=66, movieid=282, rating=3),
#  Row(userid=66, movieid=284, rating=3),
#  Row(userid=66, movieid=286, rating=1),
#  Row(userid=66, movieid=288, rating=4),
#  Row(userid=66, movieid=294, rating=4),
#  Row(userid=66, movieid=295, rating=3),
#  Row(userid=66, movieid=298, rating=4),
#  Row(userid=66, movieid=300, rating=5),
#  Row(userid=66, movieid=405, rating=3),
#  Row(userid=66, movieid=471, rating=5),
#  Row(userid=66, movieid=475, rating=2),
#  Row(userid=66, movieid=508, rating=4),
#  Row(userid=66, movieid=535, rating=4),
#  Row(userid=66, movieid=597, rating=3),
#  Row(userid=66, movieid=741, rating=4),
#  Row(userid=66, movieid=742, rating=5),
#  Row(userid=66, movieid=763, rating=4),
#  Row(userid=66, movieid=825, rating=3),
#  Row(userid=66, movieid=877, rating=1),
#  Row(userid=66, movieid=1016, rating=3),
#  Row(userid=5, movieid=1, rating=4),
#  Row(userid=5, movieid=2, rating=3),
#  Row(userid=5, movieid=17, rating=4),
#  Row(userid=5, movieid=21, rating=3),
#  Row(userid=5, movieid=24, rating=4),
#  Row(userid=5, movieid=25, rating=3),
#  Row(userid=5, movieid=29, rating=4),
#  Row(userid=5, movieid=40, rating=4),
#  Row(userid=5, movieid=42, rating=5),
#  Row(userid=5, movieid=50, rating=4),
#  Row(userid=5, movieid=62, rating=4),
#  Row(userid=5, movieid=63, rating=1),
#  Row(userid=5, movieid=66, rating=1),
#  Row(userid=5, movieid=69, rating=1),
#  Row(userid=5, movieid=70, rating=4),
#  Row(userid=5, movieid=79, rating=3),
#  Row(userid=5, movieid=80, rating=2),
#  Row(userid=5, movieid=89, rating=5),
#  Row(userid=5, movieid=90, rating=3),
#  Row(userid=5, movieid=94, rating=3),
#  Row(userid=5, movieid=95, rating=4),
#  Row(userid=5, movieid=98, rating=3),
#  Row(userid=5, movieid=99, rating=3),
#  Row(userid=5, movieid=100, rating=5),
#  Row(userid=5, movieid=101, rating=5),
#  Row(userid=5, movieid=102, rating=3),
#  Row(userid=5, movieid=105, rating=3),
#  Row(userid=5, movieid=109, rating=5),
#  Row(userid=5, movieid=110, rating=1),
#  Row(userid=5, movieid=121, rating=4),
#  Row(userid=5, movieid=135, rating=4),
#  Row(userid=5, movieid=139, rating=3),
#  Row(userid=5, movieid=143, rating=3),
#  Row(userid=5, movieid=144, rating=3),
#  Row(userid=5, movieid=145, rating=1),
#  Row(userid=5, movieid=151, rating=3),
#  Row(userid=5, movieid=153, rating=5),
#  Row(userid=5, movieid=154, rating=3),
#  Row(userid=5, movieid=162, rating=1),
#  Row(userid=5, movieid=163, rating=5),
#  Row(userid=5, movieid=167, rating=2),
#  Row(userid=5, movieid=168, rating=3),
#  Row(userid=5, movieid=169, rating=5),
#  Row(userid=5, movieid=172, rating=5),
#  Row(userid=5, movieid=173, rating=4),
#  Row(userid=5, movieid=174, rating=5),
#  Row(userid=5, movieid=176, rating=3),
#  Row(userid=5, movieid=181, rating=5),
#  Row(userid=5, movieid=183, rating=4),
#  Row(userid=5, movieid=185, rating=3),
#  Row(userid=5, movieid=186, rating=5),
#  Row(userid=5, movieid=189, rating=5),
#  Row(userid=5, movieid=194, rating=4),
#  Row(userid=5, movieid=200, rating=2),
#  Row(userid=5, movieid=204, rating=4),
#  Row(userid=5, movieid=208, rating=4),
#  Row(userid=5, movieid=209, rating=5),
#  Row(userid=5, movieid=210, rating=3),
#  Row(userid=5, movieid=211, rating=4),
#  Row(userid=5, movieid=214, rating=3),
#  Row(userid=5, movieid=216, rating=1),
#  Row(userid=5, movieid=219, rating=3),
#  Row(userid=5, movieid=222, rating=4),
#  Row(userid=5, movieid=225, rating=2),
#  Row(userid=5, movieid=226, rating=3),
#  Row(userid=5, movieid=227, rating=4),
#  Row(userid=5, movieid=228, rating=5),
#  Row(userid=5, movieid=229, rating=2),
#  Row(userid=5, movieid=230, rating=3),
#  Row(userid=5, movieid=231, rating=2),
#  Row(userid=5, movieid=233, rating=4),
#  Row(userid=5, movieid=234, rating=2),
#  Row(userid=5, movieid=235, rating=4),
#  Row(userid=5, movieid=239, rating=4),
#  Row(userid=5, movieid=241, rating=1),
#  Row(userid=5, movieid=243, rating=1),
#  Row(userid=5, movieid=250, rating=3),
#  Row(userid=5, movieid=257, rating=5),
#  Row(userid=5, movieid=259, rating=1),
#  Row(userid=5, movieid=267, rating=4),
#  Row(userid=5, movieid=363, rating=3),
#  Row(userid=5, movieid=364, rating=1),
#  Row(userid=5, movieid=365, rating=1),
#  Row(userid=5, movieid=366, rating=3),
#  Row(userid=5, movieid=367, rating=3),
#  Row(userid=5, movieid=368, rating=1),
#  Row(userid=5, movieid=369, rating=1),
#  Row(userid=5, movieid=370, rating=1),
#  Row(userid=5, movieid=371, rating=1),
#  Row(userid=5, movieid=372, rating=3),
#  Row(userid=5, movieid=373, rating=3),
#  Row(userid=5, movieid=374, rating=3),
#  Row(userid=5, movieid=375, rating=3),
#  Row(userid=5, movieid=376, rating=2),
#  Row(userid=5, movieid=377, rating=1),
#  Row(userid=5, movieid=378, rating=1),
#  Row(userid=5, movieid=379, rating=3),
#  Row(userid=5, movieid=380, rating=3),
#  Row(userid=5, movieid=381, rating=1),
#  Row(userid=5, movieid=382, rating=5),
#  Row(userid=5, movieid=383, rating=3),
#  Row(userid=5, movieid=384, rating=3),
#  Row(userid=5, movieid=385, rating=4),
#  Row(userid=5, movieid=386, rating=2),
#  Row(userid=5, movieid=387, rating=3),
#  Row(userid=5, movieid=388, rating=2),
#  Row(userid=5, movieid=389, rating=1),
#  Row(userid=5, movieid=390, rating=5),
#  Row(userid=5, movieid=391, rating=4),
#  Row(userid=5, movieid=392, rating=2),
#  Row(userid=5, movieid=393, rating=2),
#  Row(userid=5, movieid=394, rating=2),
#  Row(userid=5, movieid=395, rating=2),
#  Row(userid=5, movieid=396, rating=5),
#  Row(userid=5, movieid=397, rating=2),
#  Row(userid=5, movieid=398, rating=2),
#  Row(userid=5, movieid=399, rating=3),
#  Row(userid=5, movieid=400, rating=1),
#  Row(userid=5, movieid=401, rating=5),
#  Row(userid=5, movieid=402, rating=1),
#  Row(userid=5, movieid=403, rating=3),
#  Row(userid=5, movieid=404, rating=2),
#  Row(userid=5, movieid=405, rating=3),
#  Row(userid=5, movieid=406, rating=1),
#  Row(userid=5, movieid=407, rating=3),
#  Row(userid=5, movieid=408, rating=5),
#  Row(userid=5, movieid=409, rating=2),
#  Row(userid=5, movieid=410, rating=1),
#  Row(userid=5, movieid=411, rating=1),
#  Row(userid=5, movieid=412, rating=3),
#  Row(userid=5, movieid=413, rating=3),
#  Row(userid=5, movieid=414, rating=3),
#  Row(userid=5, movieid=415, rating=1),
#  Row(userid=5, movieid=416, rating=1),
#  Row(userid=5, movieid=417, rating=3),
#  Row(userid=5, movieid=418, rating=3),
#  Row(userid=5, movieid=419, rating=3),
#  Row(userid=5, movieid=420, rating=3),
#  Row(userid=5, movieid=421, rating=1),
#  Row(userid=5, movieid=422, rating=4),
#  Row(userid=5, movieid=423, rating=4),
#  Row(userid=5, movieid=424, rating=1),
#  Row(userid=5, movieid=425, rating=2),
#  Row(userid=5, movieid=426, rating=3),
#  Row(userid=5, movieid=427, rating=3),
#  Row(userid=5, movieid=428, rating=5),
#  Row(userid=5, movieid=429, rating=3),
#  Row(userid=5, movieid=430, rating=5),
#  Row(userid=5, movieid=431, rating=3),
#  Row(userid=5, movieid=432, rating=4),
#  Row(userid=5, movieid=433, rating=5),
#  Row(userid=5, movieid=434, rating=5),
#  Row(userid=5, movieid=435, rating=4),
#  Row(userid=5, movieid=436, rating=5),
#  Row(userid=5, movieid=437, rating=1),
#  Row(userid=5, movieid=438, rating=1),
#  Row(userid=5, movieid=439, rating=1),
#  Row(userid=5, movieid=440, rating=1),
#  Row(userid=5, movieid=441, rating=1),
#  Row(userid=5, movieid=442, rating=1),
#  Row(userid=5, movieid=443, rating=4),
#  Row(userid=5, movieid=444, rating=2),
#  Row(userid=5, movieid=445, rating=3),
#  Row(userid=5, movieid=446, rating=4),
#  Row(userid=5, movieid=447, rating=3),
#  Row(userid=5, movieid=448, rating=2),
#  Row(userid=5, movieid=449, rating=2),
#  Row(userid=5, movieid=450, rating=1),
#  Row(userid=5, movieid=451, rating=1),
#  Row(userid=5, movieid=452, rating=1),
#  Row(userid=5, movieid=453, rating=1),
#  Row(userid=5, movieid=454, rating=1),
#  Row(userid=5, movieid=455, rating=4),
#  Row(userid=5, movieid=456, rating=1),
#  Row(userid=5, movieid=457, rating=1),
#  Row(userid=109, movieid=1, rating=4),
#  Row(userid=109, movieid=4, rating=2),
#  Row(userid=109, movieid=5, rating=3),
#  Row(userid=109, movieid=7, rating=4),
#  Row(userid=109, movieid=8, rating=3),
#  ...]

# %%
rank = 10
numIterations = 10
model = ALS.train(rdd, rank, numIterations)

# %%
# Evaluate the model on training data
testdata = rdd.map(lambda p: (p[0], p[1]))
predictions = model.predictAll(testdata).map(lambda r: ((r[0], r[1]), r[2]))
ratesAndPreds = rdd.map(lambda r: ((r[0], r[1]), r[2])).join(predictions)
MSE = ratesAndPreds.map(lambda r: (r[1][0] - r[1][1])**2).mean()
print("Mean Squared Error = " + str(MSE))
# Out:
# Mean Squared Error = 0.482866938217

# %%
predictions.take(10)
# Out:
# [((195, 1084), 3.2436152153253905),
#  ((58, 1084), 4.027535289101067),
#  ((541, 1084), 4.131719831741616),
#  ((470, 1084), 3.488885567524587),
#  ((682, 1084), 3.130233794880074),
#  ((74, 1084), 2.8759141200364375),
#  ((316, 1084), 4.174448796575171),
#  ((601, 1084), 4.621236848009172),
#  ((821, 1084), 4.939130047610788),
#  ((330, 1084), 4.2138049218214935)]

# %%
ratesAndPreds.take(10)
# Out:
# [((621, 577), (3, 2.5526201383766853)),
#  ((877, 727), (4, 3.074980703210063)),
#  ((109, 365), (4, 3.2157246022485095)),
#  ((254, 622), (4, 3.3793629108665004)),
#  ((720, 286), (5, 3.9980674249100767)),
#  ((42, 294), (4, 3.920498237306166)),
#  ((812, 326), (4, 3.865893000610808)),
#  ((690, 1028), (4, 2.6361907203806014)),
#  ((321, 357), (4, 3.7774230959635897)),
#  ((363, 849), (2, 1.8612352543655915))]

# %%
spark.stop()

# %%
p_movies =model.recommendProductsForUsers(5)

# %%
p_users = model.recommendUsersForProducts(5)

# %%
p_movies.collect()
# Out:
# [(451,
#   (Rating(user=451, product=769, rating=6.780075034653405),
#    Rating(user=451, product=34, rating=6.5905502856861276),
#    Rating(user=451, product=1478, rating=6.500841588977142),
#    Rating(user=451, product=1297, rating=6.344088448753819),
#    Rating(user=451, product=1282, rating=6.271080260282858))),
#  (454,
#   (Rating(user=454, product=1278, rating=4.693832668565954),
#    Rating(user=454, product=1446, rating=4.679378875080206),
#    Rating(user=454, product=1242, rating=4.617925768279835),
#    Rating(user=454, product=1286, rating=4.55351487067372),
#    Rating(user=454, product=1218, rating=4.484985054577612))),
#  (147,
#   (Rating(user=147, product=1160, rating=7.627161218507422),
#    Rating(user=147, product=1167, rating=7.53548753039938),
#    Rating(user=147, product=1174, rating=7.390776807190488),
#    Rating(user=147, product=1192, rating=7.373379207555097),
#    Rating(user=147, product=1005, rating=7.331738123911395))),
#  (155,
#   (Rating(user=155, product=1643, rating=7.265983221003747),
#    Rating(user=155, product=361, rating=5.517660037640069),
#    Rating(user=155, product=1449, rating=5.4074029608235055),
#    Rating(user=155, product=1463, rating=5.403674089475094),
#    Rating(user=155, product=136, rating=5.057956012488118))),
#  (772,
#   (Rating(user=772, product=1643, rating=9.402332120360558),
#    Rating(user=772, product=1159, rating=7.886131646251194),
#    Rating(user=772, product=909, rating=7.789748805639441),
#    Rating(user=772, product=1093, rating=7.150086413937386),
#    Rating(user=772, product=1141, rating=6.8924411643161605))),
#  (752,
#   (Rating(user=752, product=1154, rating=9.133346498425501),
#    Rating(user=752, product=1205, rating=8.166517570423),
#    Rating(user=752, product=1368, rating=7.672890967594496),
#    Rating(user=752, product=958, rating=7.619306587189999),
#    Rating(user=752, product=1097, rating=7.482878246585758))),
#  (586,
#   (Rating(user=586, product=1131, rating=5.544057795282517),
#    Rating(user=586, product=624, rating=5.2334631602971),
#    Rating(user=586, product=1368, rating=5.15127030825112),
#    Rating(user=586, product=904, rating=4.991882330787743),
#    Rating(user=586, product=1275, rating=4.94946160059978))),
#  (667,
#   (Rating(user=667, product=1598, rating=8.10452479812717),
#    Rating(user=667, product=1069, rating=8.09708038745754),
#    Rating(user=667, product=557, rating=7.752397044816517),
#    Rating(user=667, product=1010, rating=7.653131802131202),
#    Rating(user=667, product=6, rating=7.452577097981987))),
#  (428,
#   (Rating(user=428, product=904, rating=5.9765236197114735),
#    Rating(user=428, product=1166, rating=5.740006450003826),
#    Rating(user=428, product=698, rating=5.724368217715429),
#    Rating(user=428, product=1598, rating=5.573322361783962),
#    Rating(user=428, product=557, rating=5.512903337447805))),
#  (464,
#   (Rating(user=464, product=1154, rating=6.479289794271409),
#    Rating(user=464, product=1097, rating=5.847484779676562),
#    Rating(user=464, product=1167, rating=5.789027783945643),
#    Rating(user=464, product=580, rating=5.75038858591738),
#    Rating(user=464, product=958, rating=5.697106587380096))),
#  (11,
#   (Rating(user=11, product=1643, rating=5.1886076323979395),
#    Rating(user=11, product=1463, rating=5.181227115201514),
#    Rating(user=11, product=1426, rating=5.174926073594832),
#    Rating(user=11, product=1160, rating=5.151225672891847),
#    Rating(user=11, product=867, rating=5.126826128210141))),
#  (14,
#   (Rating(user=14, product=998, rating=8.989230175908643),
#    Rating(user=14, product=718, rating=8.60595356996697),
#    Rating(user=14, product=791, rating=8.37952124844396),
#    Rating(user=14, product=1375, rating=8.373457407324898),
#    Rating(user=14, product=1478, rating=8.121301027181813))),
#  (466,
#   (Rating(user=466, product=320, rating=7.724176233201673),
#    Rating(user=466, product=904, rating=7.374247077342405),
#    Rating(user=466, product=593, rating=6.714652213146461),
#    Rating(user=466, product=698, rating=6.553010076347099),
#    Rating(user=466, product=1058, rating=6.506537666988937))),
#  (912,
#   (Rating(user=912, product=1643, rating=8.381516056968906),
#    Rating(user=912, product=464, rating=7.534999598290035),
#    Rating(user=912, product=1209, rating=7.431205939792793),
#    Rating(user=912, product=953, rating=7.267682704371952),
#    Rating(user=912, product=537, rating=6.952395684626989))),
#  (302,
#   (Rating(user=302, product=1077, rating=8.128453781744588),
#    Rating(user=302, product=390, rating=7.866992568135739),
#    Rating(user=302, product=874, rating=7.761964234050578),
#    Rating(user=302, product=253, rating=7.517343844651201),
#    Rating(user=302, product=1205, rating=7.005693177237083))),
#  (140,
#   (Rating(user=140, product=1643, rating=8.353606423742358),
#    Rating(user=140, product=1463, rating=7.144343381760585),
#    Rating(user=140, product=427, rating=6.1987386689545705),
#    Rating(user=140, product=1141, rating=6.19287970708371),
#    Rating(user=140, product=496, rating=6.14704603724205))),
#  (204,
#   (Rating(user=204, product=1463, rating=7.823221788386004),
#    Rating(user=204, product=624, rating=7.583729545637593),
#    Rating(user=204, product=1094, rating=7.4156342314535255),
#    Rating(user=204, product=1512, rating=7.1158549263262625),
#    Rating(user=204, product=1069, rating=7.103597369582726))),
#  (195,
#   (Rating(user=195, product=1463, rating=5.760931002742123),
#    Rating(user=195, product=1169, rating=5.569120819545986),
#    Rating(user=195, product=836, rating=5.532393589869457),
#    Rating(user=195, product=1643, rating=5.3762379847568855),
#    Rating(user=195, product=1075, rating=5.332635602673863))),
#  (215,
#   (Rating(user=215, product=1643, rating=5.913010036497155),
#    Rating(user=215, product=718, rating=5.899240601246963),
#    Rating(user=215, product=361, rating=5.719139143022487),
#    Rating(user=215, product=1286, rating=5.70878655814688),
#    Rating(user=215, product=793, rating=5.567467732851985))),
#  (1,
#   (Rating(user=1, product=1643, rating=6.537995468579694),
#    Rating(user=1, product=361, rating=5.738891926452398),
#    Rating(user=1, product=1449, rating=5.623592426666457),
#    Rating(user=1, product=613, rating=5.600703512860395),
#    Rating(user=1, product=718, rating=5.239716120285626))),
#  (226,
#   (Rating(user=226, product=850, rating=7.8062821088420815),
#    Rating(user=226, product=965, rating=7.638161833919199),
#    Rating(user=226, product=1154, rating=7.572300306757671),
#    Rating(user=226, product=1159, rating=7.406190931073378),
#    Rating(user=226, product=1166, rating=7.342603535052712))),
#  (291,
#   (Rating(user=291, product=1643, rating=6.291341062957612),
#    Rating(user=291, product=1449, rating=5.9641625226137505),
#    Rating(user=291, product=1368, rating=5.906439978186868),
#    Rating(user=291, product=884, rating=5.742056682757275),
#    Rating(user=291, product=913, rating=5.6334375502965806))),
#  (318,
#   (Rating(user=318, product=1242, rating=6.473914633193693),
#    Rating(user=318, product=1167, rating=5.9928592251136825),
#    Rating(user=318, product=1172, rating=5.351002701769468),
#    Rating(user=318, product=1192, rating=5.34766536888905),
#    Rating(user=318, product=1438, rating=5.332326001103491))),
#  (931,
#   (Rating(user=931, product=1438, rating=6.335019119321169),
#    Rating(user=931, product=1160, rating=6.00919231488129),
#    Rating(user=931, product=697, rating=5.792923504561129),
#    Rating(user=931, product=1252, rating=5.739311254303305),
#    Rating(user=931, product=1167, rating=5.723961057907902))),
#  (443,
#   (Rating(user=443, product=960, rating=12.31789807277569),
#    Rating(user=443, product=1185, rating=12.213039457923436),
#    Rating(user=443, product=1006, rating=10.50503292818388),
#    Rating(user=443, product=775, rating=10.313801487910338),
#    Rating(user=443, product=1164, rating=10.233535031368293))),
#  (755,
#   (Rating(user=755, product=1438, rating=8.73371520016419),
#    Rating(user=755, product=1242, rating=8.723360691606867),
#    Rating(user=755, product=1160, rating=7.552721852245133),
#    Rating(user=755, product=1167, rating=7.5474296062221615),
#    Rating(user=755, product=1426, rating=6.997694323048323))),
#  (228,
#   (Rating(user=228, product=775, rating=10.801159398067206),
#    Rating(user=228, product=1297, rating=10.245723263802123),
#    Rating(user=228, product=1192, rating=9.827076657100116),
#    Rating(user=228, product=1531, rating=9.777943614394736),
#    Rating(user=228, product=1262, rating=9.745580988877087))),
#  (94,
#   (Rating(user=94, product=1643, rating=6.860359688100276),
#    Rating(user=94, product=1449, rating=5.825754289544779),
#    Rating(user=94, product=1368, rating=5.636678898633406),
#    Rating(user=94, product=1463, rating=5.568056349064051),
#    Rating(user=94, product=1405, rating=5.559133594954873))),
#  (192,
#   (Rating(user=192, product=906, rating=8.104904432269505),
#    Rating(user=192, product=960, rating=6.773118595333493),
#    Rating(user=192, product=253, rating=6.6280643983181236),
#    Rating(user=192, product=1114, rating=6.22848674603852),
#    Rating(user=192, product=874, rating=6.227950268839638))),
#  (450,
#   (Rating(user=450, product=1643, rating=5.801390693254384),
#    Rating(user=450, product=1169, rating=5.279882293666903),
#    Rating(user=450, product=1141, rating=5.260387564882155),
#    Rating(user=450, product=318, rating=5.246629079583187),
#    Rating(user=450, product=1438, rating=5.137939215844151))),
#  (160,
#   (Rating(user=160, product=1368, rating=7.846410148521105),
#    Rating(user=160, product=1062, rating=5.621055824617222),
#    Rating(user=160, product=913, rating=5.5890833035262935),
#    Rating(user=160, product=1380, rating=5.57270756726935),
#    Rating(user=160, product=1643, rating=5.57204581566284))),
#  (492,
#   (Rating(user=492, product=1093, rating=8.550855197838597),
#    Rating(user=492, product=1643, rating=8.142772469609785),
#    Rating(user=492, product=464, rating=8.076487979104883),
#    Rating(user=492, product=1058, rating=7.662877408278774),
#    Rating(user=492, product=1335, rating=7.399505971978525))),
#  (21,
#   (Rating(user=21, product=1643, rating=6.259381020914182),
#    Rating(user=21, product=1512, rating=5.3378205896644175),
#    Rating(user=21, product=361, rating=5.324436565231236),
#    Rating(user=21, product=1449, rating=5.226728410751328),
#    Rating(user=21, product=1368, rating=5.218984305435086))),
#  (321,
#   (Rating(user=321, product=1643, rating=5.513739725312776),
#    Rating(user=321, product=361, rating=5.417858100808643),
#    Rating(user=321, product=1286, rating=4.945022982776274),
#    Rating(user=321, product=1024, rating=4.92368624905487),
#    Rating(user=321, product=1167, rating=4.915156055152862))),
#  (577,
#   (Rating(user=577, product=1153, rating=5.845261320370582),
#    Rating(user=577, product=1160, rating=5.779469126366646),
#    Rating(user=577, product=1426, rating=5.5984777564211665),
#    Rating(user=577, product=776, rating=5.5377618614473185),
#    Rating(user=577, product=1166, rating=5.499274858256513))),
#  (715,
#   (Rating(user=715, product=1001, rating=5.702301713245751),
#    Rating(user=715, product=1181, rating=5.66566430306724),
#    Rating(user=715, product=1598, rating=5.565941273810779),
#    Rating(user=715, product=613, rating=5.518800244550734),
#    Rating(user=715, product=1470, rating=5.395698102681095))),
#  (403,
#   (Rating(user=403, product=1154, rating=6.578725246066668),
#    Rating(user=403, product=1166, rating=6.336585414975111),
#    Rating(user=403, product=1086, rating=6.168005193477067),
#    Rating(user=403, product=667, rating=6.081329566864491),
#    Rating(user=403, product=1268, rating=6.069667839934282))),
#  (355,
#   (Rating(user=355, product=904, rating=7.856069772980711),
#    Rating(user=355, product=698, rating=7.2306756444963725),
#    Rating(user=355, product=1324, rating=7.01453238373754),
#    Rating(user=355, product=1176, rating=6.976990801862346),
#    Rating(user=355, product=593, rating=6.88199517158565))),
#  (801,
#   (Rating(user=801, product=1001, rating=10.550153087279675),
#    Rating(user=801, product=962, rating=9.535480984146703),
#    Rating(user=801, product=1114, rating=9.233405578751684),
#    Rating(user=801, product=253, rating=8.82976681361169),
#    Rating(user=801, product=1297, rating=8.354891709371932))),
#  (460,
#   (Rating(user=460, product=1174, rating=7.206173499553716),
#    Rating(user=460, product=1167, rating=6.853555281290369),
#    Rating(user=460, product=1154, rating=6.405442114834459),
#    Rating(user=460, product=536, rating=6.092547452839887),
#    Rating(user=460, product=1192, rating=5.971657199822952))),
#  (131,
#   (Rating(user=131, product=1160, rating=12.460013058282842),
#    Rating(user=131, product=624, rating=12.24590922178535),
#    Rating(user=131, product=1478, rating=11.05316754525531),
#    Rating(user=131, product=1131, rating=10.54204332378728),
#    Rating(user=131, product=865, rating=10.53576868928512))),
#  (815,
#   (Rating(user=815, product=1141, rating=6.894513810994872),
#    Rating(user=815, product=1159, rating=6.778077440560577),
#    Rating(user=815, product=1173, rating=6.588418984713054),
#    Rating(user=815, product=884, rating=6.569532069071704),
#    Rating(user=815, product=1086, rating=6.532648173741215))),
#  (347,
#   (Rating(user=347, product=320, rating=7.582942319833475),
#    Rating(user=347, product=695, rating=7.4328775232711095),
#    Rating(user=347, product=1022, rating=7.430527982437398),
#    Rating(user=347, product=1128, rating=7.409313521601789),
#    Rating(user=347, product=1643, rating=7.070804888508454))),
#  (799,
#   (Rating(user=799, product=1643, rating=8.517766371133238),
#    Rating(user=799, product=1160, rating=7.190665195056081),
#    Rating(user=799, product=1058, rating=6.953166446480784),
#    Rating(user=799, product=464, rating=6.898993780318474),
#    Rating(user=799, product=909, rating=6.782087604007676))),
#  (548,
#   (Rating(user=548, product=1159, rating=9.619046807826415),
#    Rating(user=548, product=1483, rating=8.168053007408492),
#    Rating(user=548, product=1141, rating=7.553273635421148),
#    Rating(user=548, product=1313, rating=7.237993475520375),
#    Rating(user=548, product=1229, rating=7.202797943727291))),
#  (637,
#   (Rating(user=637, product=1286, rating=6.829076505725032),
#    Rating(user=637, product=1503, rating=5.941212055106222),
#    Rating(user=637, product=1167, rating=5.934497295425166),
#    Rating(user=637, product=1242, rating=5.626675596368301),
#    Rating(user=637, product=308, rating=5.506077779652343))),
#  (646,
#   (Rating(user=646, product=624, rating=5.501792340385585),
#    Rating(user=646, product=1131, rating=5.331854828757156),
#    Rating(user=646, product=904, rating=5.062327839057127),
#    Rating(user=646, product=698, rating=4.916183279880771),
#    Rating(user=646, product=1438, rating=4.893096728609154))),
#  (293,
#   (Rating(user=293, product=1643, rating=6.801676611441632),
#    Rating(user=293, product=1463, rating=4.98090866321006),
#    Rating(user=293, product=361, rating=4.966224335251586),
#    Rating(user=293, product=1142, rating=4.848907910326848),
#    Rating(user=293, product=1368, rating=4.839792352665137))),
#  (93,
#   (Rating(user=93, product=1154, rating=12.224550621698578),
#    Rating(user=93, product=353, rating=9.974394170862519),
#    Rating(user=93, product=791, rating=9.873027648038256),
#    Rating(user=93, product=916, rating=9.800763508551206),
#    Rating(user=93, product=1120, rating=9.601812236898713))),
#  (489,
#   (Rating(user=489, product=1615, rating=8.917667423759987),
#    Rating(user=489, product=1131, rating=8.78782997400161),
#    Rating(user=489, product=592, rating=8.497282996989163),
#    Rating(user=489, product=624, rating=8.212155645431498),
#    Rating(user=489, product=555, rating=8.000591946191918))),
#  (758,
#   (Rating(user=758, product=1643, rating=6.748894628673961),
#    Rating(user=758, product=1449, rating=6.080520384235559),
#    Rating(user=758, product=613, rating=5.7221816782077966),
#    Rating(user=758, product=361, rating=5.566581908936176),
#    Rating(user=758, product=1589, rating=5.519023456908628))),
#  (528,
#   (Rating(user=528, product=667, rating=6.591276632398273),
#    Rating(user=528, product=1598, rating=6.403153310985598),
#    Rating(user=528, product=1142, rating=6.395903962076723),
#    Rating(user=528, product=1001, rating=6.361730444154815),
#    Rating(user=528, product=1181, rating=6.334880196333854))),
#  (696,
#   (Rating(user=696, product=1174, rating=8.32138942285797),
#    Rating(user=696, product=1426, rating=8.287671636450973),
#    Rating(user=696, product=1167, rating=8.193310266120825),
#    Rating(user=696, product=1024, rating=7.55345022785853),
#    Rating(user=696, product=1242, rating=7.35617098213879))),
#  (558,
#   (Rating(user=558, product=960, rating=8.633728928449361),
#    Rating(user=558, product=1022, rating=8.438216555599265),
#    Rating(user=558, product=1184, rating=8.32680016753693),
#    Rating(user=558, product=906, rating=7.840831420875379),
#    Rating(user=558, product=1368, rating=7.605506509173164))),
#  (453,
#   (Rating(user=453, product=1368, rating=5.460362963334054),
#    Rating(user=453, product=884, rating=5.386171211727531),
#    Rating(user=453, product=1598, rating=5.255984998072769),
#    Rating(user=453, product=1449, rating=5.229091265523965),
#    Rating(user=453, product=296, rating=5.154985667903196))),
#  (58,
#   (Rating(user=58, product=962, rating=7.113408021185733),
#    Rating(user=58, product=793, rating=6.906120741720605),
#    Rating(user=58, product=1114, rating=6.873714212441665),
#    Rating(user=58, product=1184, rating=6.859746079725094),
#    Rating(user=58, product=916, rating=6.713647370628878))),
#  (599,
#   (Rating(user=599, product=1164, rating=6.1975690473450396),
#    Rating(user=599, product=1336, rating=6.044191402994917),
#    Rating(user=599, product=1075, rating=6.02153560719717),
#    Rating(user=599, product=1279, rating=5.792368391707098),
#    Rating(user=599, product=1227, rating=5.759022965873659))),
#  (855,
#   (Rating(user=855, product=962, rating=7.167553471510617),
#    Rating(user=855, product=915, rating=6.690227311515526),
#    Rating(user=855, product=898, rating=6.642447351428912),
#    Rating(user=855, product=793, rating=6.59293228300406),
#    Rating(user=855, product=1234, rating=6.47957492304981))),
#  (878,
#   (Rating(user=878, product=1643, rating=6.26376154060107),
#    Rating(user=878, product=1242, rating=5.620518608362074),
#    Rating(user=878, product=361, rating=5.39120853465932),
#    Rating(user=878, product=1024, rating=5.311466524751729),
#    Rating(user=878, product=1426, rating=5.043505991326053))),
#  (196,
#   (Rating(user=196, product=1160, rating=9.073890635791278),
#    Rating(user=196, product=1283, rating=8.353531061138773),
#    Rating(user=196, product=1094, rating=8.344962619860855),
#    Rating(user=196, product=1183, rating=7.71520668129593),
#    Rating(user=196, product=998, rating=7.513268565498468))),
#  (929,
#   (Rating(user=929, product=1643, rating=7.437780284502285),
#    Rating(user=929, product=1438, rating=6.464148980335342),
#    Rating(user=929, product=1159, rating=6.233715847306833),
#    Rating(user=929, product=909, rating=6.053553809761109),
#    Rating(user=929, product=574, rating=5.861748892808172))),
#  (338,
#   (Rating(user=338, product=361, rating=7.007151729322993),
#    Rating(user=338, product=1174, rating=6.68427567855482),
#    Rating(user=338, product=536, rating=6.663645931283917),
#    Rating(user=338, product=1368, rating=6.498511297387966),
#    Rating(user=338, product=1643, rating=6.489638007237261))),
#  (784,
#   (Rating(user=784, product=1166, rating=5.275249061848074),
#    Rating(user=784, product=1282, rating=5.062537277141284),
#    Rating(user=784, product=1631, rating=5.0527957530786125),
#    Rating(user=784, product=1639, rating=4.951866328099131),
#    Rating(user=784, product=1385, rating=4.840074119132889))),
#  (848,
#   (Rating(user=848, product=916, rating=8.617710364943504),
#    Rating(user=848, product=1052, rating=8.462753645155594),
#    Rating(user=848, product=1153, rating=8.395395172727458),
#    Rating(user=848, product=1160, rating=8.33003963908521),
#    Rating(user=848, product=361, rating=8.043250357310622))),
#  (387,
#   (Rating(user=387, product=1368, rating=7.092605615793729),
#    Rating(user=387, product=1643, rating=6.461782301823663),
#    Rating(user=387, product=848, rating=6.459700221065146),
#    Rating(user=387, product=390, rating=6.448999965205583),
#    Rating(user=387, product=1159, rating=6.357288245032866))),
#  (918,
#   (Rating(user=918, product=1426, rating=8.039741283835422),
#    Rating(user=918, product=1052, rating=6.7754975113863605),
#    Rating(user=918, product=1160, rating=6.540816511065802),
#    Rating(user=918, product=1174, rating=6.450787240924443),
#    Rating(user=918, product=1120, rating=6.420799194277159))),
#  (292,
#   (Rating(user=292, product=1643, rating=7.070153630217111),
#    Rating(user=292, product=1368, rating=5.921965811978471),
#    Rating(user=292, product=1449, rating=5.796172739569403),
#    Rating(user=292, product=1463, rating=5.42058752662169),
#    Rating(user=292, product=1159, rating=5.344273050830093))),
#  (79,
#   (Rating(user=79, product=1643, rating=8.6109469679133),
#    Rating(user=79, product=464, rating=8.298037923569604),
#    Rating(user=79, product=1058, rating=8.265185511204674),
#    Rating(user=79, product=1160, rating=7.687222571093393),
#    Rating(user=79, product=361, rating=6.935083200758858))),
#  (375,
#   (Rating(user=375, product=1286, rating=7.054473925560077),
#    Rating(user=375, product=1173, rating=6.767348893755459),
#    Rating(user=375, product=1038, rating=6.704581627610182),
#    Rating(user=375, product=1463, rating=6.580612540474605),
#    Rating(user=375, product=1643, rating=6.52453657429427))),
#  (835,
#   (Rating(user=835, product=1160, rating=7.004744371421622),
#    Rating(user=835, product=1438, rating=6.490881951365655),
#    Rating(user=835, product=1643, rating=6.045909294019066),
#    Rating(user=835, product=697, rating=5.9079465935416176),
#    Rating(user=835, product=1426, rating=5.837768054693935))),
#  (30,
#   (Rating(user=30, product=1643, rating=6.748670622174925),
#    Rating(user=30, product=904, rating=6.55183620882996),
#    Rating(user=30, product=1166, rating=6.375828282623484),
#    Rating(user=30, product=1160, rating=6.336093515453067),
#    Rating(user=30, product=698, rating=6.245137132000875))),
#  (127,
#   (Rating(user=127, product=374, rating=11.097701362821176),
#    Rating(user=127, product=446, rating=10.449610379056391),
#    Rating(user=127, product=1469, rating=10.422727312252839),
#    Rating(user=127, product=263, rating=9.612954400286496),
#    Rating(user=127, product=862, rating=9.546216845442018))),
#  (754,
#   (Rating(user=754, product=1598, rating=6.974278221395913),
#    Rating(user=754, product=1425, rating=6.672465397215008),
#    Rating(user=754, product=667, rating=6.11356858846311),
#    Rating(user=754, product=1311, rating=6.037423034365463),
#    Rating(user=754, product=1117, rating=6.007408736685465))),
#  (603,
#   (Rating(user=603, product=1086, rating=8.794154964684564),
#    Rating(user=603, product=353, rating=8.727244968287202),
#    Rating(user=603, product=850, rating=8.464624257541713),
#    Rating(user=603, product=394, rating=8.303220352737348),
#    Rating(user=603, product=884, rating=8.204228266831427))),
#  (275,
#   (Rating(user=275, product=1643, rating=4.524397717859504),
#    Rating(user=275, product=733, rating=3.9179748007002653),
#    Rating(user=275, product=50, rating=3.90852326339223),
#    Rating(user=275, product=174, rating=3.904757103809557),
#    Rating(user=275, product=1449, rating=3.8804361443927475))),
#  (266,
#   (Rating(user=266, product=718, rating=6.676530678056724),
#    Rating(user=266, product=497, rating=6.579309707031538),
#    Rating(user=266, product=489, rating=6.3338793009039085),
#    Rating(user=266, product=1347, rating=6.247971584342448),
#    Rating(user=266, product=1397, rating=6.071845675752363))),
#  (344,
#   (Rating(user=344, product=1643, rating=6.228862859236687),
#    Rating(user=344, product=1368, rating=5.847800892162862),
#    Rating(user=344, product=361, rating=5.786414856213703),
#    Rating(user=344, product=1463, rating=5.634009214669151),
#    Rating(user=344, product=718, rating=5.5638979932381165))),
#  (541,
#   (Rating(user=541, product=115, rating=6.583876782372609),
#    Rating(user=541, product=1153, rating=6.192571622726269),
#    Rating(user=541, product=1425, rating=6.113292716753357),
#    Rating(user=541, product=1120, rating=6.057964054847916),
#    Rating(user=541, product=1052, rating=6.046084631166461))),
#  (834,
#   (Rating(user=834, product=962, rating=5.6962605911007484),
#    Rating(user=834, product=1065, rating=5.090303611755986),
#    Rating(user=834, product=1114, rating=5.049345243850896),
#    Rating(user=834, product=915, rating=5.029796635755552),
#    Rating(user=834, product=1169, rating=4.985981295722063))),
#  (741,
#   (Rating(user=741, product=1643, rating=6.835305493606459),
#    Rating(user=741, product=1176, rating=6.316744243017842),
#    Rating(user=741, product=1463, rating=5.821733901369541),
#    Rating(user=741, product=1103, rating=5.544608082158216),
#    Rating(user=741, product=701, rating=5.361051958935375))),
#  (664,
#   (Rating(user=664, product=1643, rating=7.46887004488417),
#    Rating(user=664, product=361, rating=5.94584772064159),
#    Rating(user=664, product=1463, rating=5.8850473320333165),
#    Rating(user=664, product=1126, rating=5.493949988446641),
#    Rating(user=664, product=320, rating=5.223511634016909))),
#  (252,
#   (Rating(user=252, product=960, rating=7.55896977613388),
#    Rating(user=252, product=624, rating=6.925647494709981),
#    Rating(user=252, product=865, rating=6.50524511130836),
#    Rating(user=252, product=915, rating=6.472069699535927),
#    Rating(user=252, product=1643, rating=6.455498775789188))),
#  (827,
#   (Rating(user=827, product=962, rating=6.703964740636674),
#    Rating(user=827, product=1114, rating=6.629950219315525),
#    Rating(user=827, product=916, rating=6.042132294053394),
#    Rating(user=827, product=960, rating=5.840927036944311),
#    Rating(user=827, product=1065, rating=5.524257308024491))),
#  (83,
#   (Rating(user=83, product=1141, rating=6.21809182939468),
#    Rating(user=83, product=1483, rating=5.862770584009991),
#    Rating(user=83, product=1159, rating=5.667485880556014),
#    Rating(user=83, product=394, rating=5.6240967582838675),
#    Rating(user=83, product=966, rating=5.524507836728534))),
#  (919,
#   (Rating(user=919, product=1463, rating=5.5129417658788125),
#    Rating(user=919, product=1169, rating=5.378795583974613),
#    Rating(user=919, product=1268, rating=5.3140547765314325),
#    Rating(user=919, product=1438, rating=5.242340618408145),
#    Rating(user=919, product=1097, rating=5.21358328677732))),
#  (251,
#   (Rating(user=251, product=1176, rating=6.362171690023893),
#    Rating(user=251, product=1368, rating=5.864969337807209),
#    Rating(user=251, product=701, rating=5.819260043190317),
#    Rating(user=251, product=1463, rating=5.790494478348943),
#    Rating(user=251, product=1553, rating=5.735978097494217))),
#  (9,
#   (Rating(user=9, product=1279, rating=9.380536925773988),
#    Rating(user=9, product=74, rating=9.164364205374715),
#    Rating(user=9, product=1176, rating=8.961574860840592),
#    Rating(user=9, product=698, rating=8.777856322510585),
#    Rating(user=9, product=1227, rating=8.767144328666173))),
#  (688,
#   (Rating(user=688, product=34, rating=8.304346387925943),
#    Rating(user=688, product=962, rating=8.206889333485615),
#    Rating(user=688, product=916, rating=8.135968028009401),
#    Rating(user=688, product=915, rating=7.933515638928936),
#    Rating(user=688, product=791, rating=7.738959881596445))),
#  (651,
#   (Rating(user=651, product=767, rating=14.34118097683466),
#    Rating(user=651, product=906, rating=11.453182525051515),
#    Rating(user=651, product=1438, rating=11.190330462445107),
#    Rating(user=651, product=1255, rating=10.935090311822323),
#    Rating(user=651, product=695, rating=10.385458789285579))),
#  (735,
#   (Rating(user=735, product=1113, rating=5.97953492332032),
#    Rating(user=735, product=989, rating=5.937558037818784),
#    Rating(user=735, product=1664, rating=5.607431880007372),
#    Rating(user=735, product=361, rating=5.51817665948516),
#    Rating(user=735, product=1167, rating=5.248144117399685))),
#  (423,
#   (Rating(user=423, product=1113, rating=5.761471290608268),
#    Rating(user=423, product=1643, rating=5.578333314499772),
#    Rating(user=423, product=1142, rating=5.452986021199061),
#    Rating(user=423, product=1167, rating=5.417250786747326),
#    Rating(user=423, product=1473, rating=5.215957068956181))),
#  (506,
#   (Rating(user=506, product=1643, rating=7.357873363791416),
#    Rating(user=506, product=1483, rating=5.813619399738811),
#    Rating(user=506, product=534, rating=5.726971613968281),
#    Rating(user=506, product=909, rating=5.724715523639057),
#    Rating(user=506, product=1038, rating=5.696464430750186))),
#  (467,
#   (Rating(user=467, product=361, rating=8.195029534777035),
#    Rating(user=467, product=1643, rating=7.207635271312528),
#    Rating(user=467, product=1184, rating=6.9431850777143485),
#    Rating(user=467, product=1024, rating=6.6997400427906095),
#    Rating(user=467, product=793, rating=6.6098834901555525))),
#  (592,
#   (Rating(user=592, product=1643, rating=7.148183228106865),
#    Rating(user=592, product=1449, rating=6.048986971262348),
#    Rating(user=592, product=1512, rating=5.940098550528369),
#    Rating(user=592, product=1368, rating=5.925609266842389),
#    Rating(user=592, product=127, rating=5.696495689157469))),
#  (397,
#   (Rating(user=397, product=1643, rating=8.268387868089011),
#    Rating(user=397, product=1022, rating=6.16365542143633),
#    Rating(user=397, product=361, rating=5.923556378074762),
#    Rating(user=397, product=1449, rating=5.700834012664138),
#    Rating(user=397, product=793, rating=5.6523425450435365))),
#  (836,
#   (Rating(user=836, product=1438, rating=7.83918406585902),
#    Rating(user=836, product=1159, rating=7.673898674272183),
#    Rating(user=836, product=884, rating=7.341997252485568),
#    Rating(user=836, product=1141, rating=7.060600578893068),
#    Rating(user=836, product=848, rating=6.770473740169436))),
#  (470,
#   (Rating(user=470, product=1643, rating=5.2326460059923185),
#    Rating(user=470, product=915, rating=5.081341100960653),
#    Rating(user=470, product=624, rating=5.008102625004786),
#    Rating(user=470, product=963, rating=5.004977517053024),
#    Rating(user=470, product=1449, rating=4.905389710205475))),
#  (326,
#   (Rating(user=326, product=1286, rating=9.158279174330922),
#    Rating(user=326, product=1142, rating=6.653233048688033),
#    Rating(user=326, product=1154, rating=6.516132392586433),
#    Rating(user=326, product=1503, rating=6.490604772459368),
#    Rating(user=326, product=1093, rating=6.002372363036997))),
#  (631,
#   (Rating(user=631, product=253, rating=6.1829603389933405),
#    Rating(user=631, product=1001, rating=6.127025331712388),
#    Rating(user=631, product=919, rating=6.020360614181987),
#    Rating(user=631, product=1052, rating=5.978330965699467),
#    Rating(user=631, product=613, rating=5.931223325782268))),
#  (831,
#   (Rating(user=831, product=1643, rating=7.4194119801007785),
#    Rating(user=831, product=1176, rating=5.971500938832429),
#    Rating(user=831, product=534, rating=5.942695086441631),
#    Rating(user=831, product=361, rating=5.573652725701782),
#    Rating(user=831, product=1324, rating=5.25866088043746))),
#  (863,
#   (Rating(user=863, product=960, rating=6.673844271115998),
#    Rating(user=863, product=1174, rating=6.439912367608888),
#    Rating(user=863, product=916, rating=6.1842829015894),
#    Rating(user=863, product=791, rating=6.082806173561518),
#    Rating(user=863, product=915, rating=6.047602308924391))),
#  (95,
#   (Rating(user=95, product=1154, rating=5.049597076727666),
#    Rating(user=95, product=613, rating=5.0220094730209865),
#    Rating(user=95, product=543, rating=4.975943106064948),
#    Rating(user=95, product=1120, rating=4.9652716025481425),
#    Rating(user=95, product=1344, rating=4.920488169759571))),
#  (379,
#   (Rating(user=379, product=1643, rating=7.107501157147707),
#    Rating(user=379, product=361, rating=6.208787882666192),
#    Rating(user=379, product=718, rating=5.698176183540488),
#    Rating(user=379, product=489, rating=5.193408493867623),
#    Rating(user=379, product=408, rating=5.170675613408408))),
#  (740,
#   (Rating(user=740, product=1643, rating=6.306441157819732),
#    Rating(user=740, product=1142, rating=6.092302023097938),
#    Rating(user=740, product=467, rating=5.894013627790047),
#    Rating(user=740, product=534, rating=5.795469638309366),
#    Rating(user=740, product=888, rating=5.789698105969213))),
#  (208,
#   (Rating(user=208, product=1643, rating=9.825624231795965),
#    Rating(user=208, product=1209, rating=8.883038091890853),
#    Rating(user=208, product=863, rating=8.075521876525217),
#    Rating(user=208, product=574, rating=7.567426929868963),
#    Rating(user=208, product=1426, rating=7.363249937154038))),
#  (436,
#   (Rating(user=436, product=1114, rating=6.738571653418896),
#    Rating(user=436, product=962, rating=6.618343988512665),
#    Rating(user=436, product=960, rating=6.374698966404319),
#    Rating(user=436, product=1297, rating=6.159031984122624),
#    Rating(user=436, product=1065, rating=6.039456023257537))),
#  (501,
#   (Rating(user=501, product=1368, rating=7.351375600434178),
#    Rating(user=501, product=1643, rating=6.211434143134062),
#    Rating(user=501, product=884, rating=5.995040309152665),
#    Rating(user=501, product=1449, rating=5.855202329602042),
#    Rating(user=501, product=1159, rating=5.670757673171419))),
#  (804,
#   (Rating(user=804, product=1643, rating=5.590115602489612),
#    Rating(user=804, product=1269, rating=5.457932986532484),
#    Rating(user=804, product=1159, rating=5.29864760503619),
#    Rating(user=804, product=733, rating=5.21571564455667),
#    Rating(user=804, product=50, rating=5.127654660976676))),
#  (869,
#   (Rating(user=869, product=1404, rating=6.902314214605568),
#    Rating(user=869, product=1199, rating=6.7117542047769785),
#    Rating(user=869, product=793, rating=6.5795417152596105),
#    Rating(user=869, product=837, rating=6.487430562486335),
#    Rating(user=869, product=640, rating=6.308133434318707))),
#  (259,
#   (Rating(user=259, product=1643, rating=6.260815996177722),
#    Rating(user=259, product=1368, rating=5.7059713011639746),
#    Rating(user=259, product=1449, rating=5.639728894411916),
#    Rating(user=259, product=1058, rating=5.505335760030439),
#    Rating(user=259, product=874, rating=5.484028992040265))),
#  (759,
#   (Rating(user=759, product=776, rating=7.517050448364829),
#    Rating(user=759, product=630, rating=6.780049470686921),
#    Rating(user=759, product=1001, rating=6.554448835840069),
#    Rating(user=759, product=394, rating=6.196222101656769),
#    Rating(user=759, product=1117, rating=6.132106824647899))),
#  (7,
#   (Rating(user=7, product=1643, rating=7.779078597749929),
#    Rating(user=7, product=909, rating=5.955951492038207),
#    Rating(user=7, product=1159, rating=5.72301453581696),
#    Rating(user=7, product=1141, rating=5.607890846490697),
#    Rating(user=7, product=1449, rating=5.462450236407829))),
#  (174,
#   (Rating(user=174, product=1438, rating=10.093220544160406),
#    Rating(user=174, product=394, rating=8.145249826055043),
#    Rating(user=174, product=697, rating=7.919382575249429),
#    Rating(user=174, product=1426, rating=7.739207511365848),
#    Rating(user=174, product=1216, rating=7.349895871137842))),
#  (675,
#   (Rating(user=675, product=1512, rating=7.537211773955439),
#    Rating(user=675, product=537, rating=7.017598179700183),
#    Rating(user=675, product=1643, rating=6.744433012294796),
#    Rating(user=675, product=20, rating=6.67901953063466),
#    Rating(user=675, product=960, rating=6.640962808273052))),
#  (499,
#   (Rating(user=499, product=253, rating=6.678744557415685),
#    Rating(user=499, product=1160, rating=6.396174504273926),
#    Rating(user=499, product=1639, rating=6.2686284387996665),
#    Rating(user=499, product=1005, rating=6.206549892125607),
#    Rating(user=499, product=1058, rating=6.027834774085179))),
#  (695,
#   (Rating(user=695, product=1368, rating=8.88428850922813),
#    Rating(user=695, product=793, rating=8.873152159745649),
#    Rating(user=695, product=1184, rating=8.820721626060141),
#    Rating(user=695, product=1643, rating=8.541557414811468),
#    Rating(user=695, product=320, rating=8.291530875915743))),
#  (536,
#   (Rating(user=536, product=776, rating=7.129042711493081),
#    Rating(user=536, product=1209, rating=6.965376166948438),
#    Rating(user=536, product=630, rating=6.901760475868641),
#    Rating(user=536, product=1269, rating=6.320078336723382),
#    Rating(user=536, product=613, rating=6.221979362656551))),
#  (734,
#   (Rating(user=734, product=394, rating=5.599763175953372),
#    Rating(user=734, product=143, rating=5.306358020945569),
#    Rating(user=734, product=1141, rating=5.287017594830783),
#    Rating(user=734, product=1207, rating=5.157186641898561),
#    Rating(user=734, product=1160, rating=5.1514808650006385))),
#  (34,
#   (Rating(user=34, product=1438, rating=13.303202575819359),
#    Rating(user=34, product=1159, rating=11.260293592675211),
#    Rating(user=34, product=536, rating=9.88732155468664),
#    Rating(user=34, product=1368, rating=9.852339977062003),
#    Rating(user=34, product=726, rating=9.631992506218669))),
#  (267,
#   (Rating(user=267, product=1643, rating=7.117095780153978),
#    Rating(user=267, product=1368, rating=6.310030039789069),
#    Rating(user=267, product=1449, rating=6.042915982492112),
#    Rating(user=267, product=361, rating=5.6418921373787185),
#    Rating(user=267, product=320, rating=5.444271720774794))),
#  (491,
#   (Rating(user=491, product=1643, rating=6.667987985920192),
#    Rating(user=491, product=1449, rating=6.307893617798625),
#    Rating(user=491, product=1463, rating=6.151277896875378),
#    Rating(user=491, product=998, rating=6.056737844212641),
#    Rating(user=491, product=1126, rating=6.055218542018206))),
#  (4,
#   (Rating(user=4, product=915, rating=8.27599394816441),
#    Rating(user=4, product=1192, rating=6.987749796668538),
#    Rating(user=4, product=624, rating=6.871342798183518),
#    Rating(user=4, product=1131, rating=6.807614926285808),
#    Rating(user=4, product=1167, rating=6.635127436867995))),
#  (327,
#   (Rating(user=327, product=1643, rating=5.256182728383563),
#    Rating(user=327, product=1512, rating=5.177523423942386),
#    Rating(user=327, product=1463, rating=5.100886667202836),
#    Rating(user=327, product=1266, rating=4.722453625282913),
#    Rating(user=327, product=1449, rating=4.721910010841507))),
#  (150,
#   (Rating(user=150, product=962, rating=6.2111764622354375),
#    Rating(user=150, product=1114, rating=6.180548047061578),
#    Rating(user=150, product=1368, rating=6.082875662197653),
#    Rating(user=150, product=1184, rating=5.9710193611872615),
#    Rating(user=150, product=960, rating=5.695064724162678))),
#  (417,
#   (Rating(user=417, product=1643, rating=5.771913578325782),
#    Rating(user=417, product=1449, rating=5.256600322730865),
#    Rating(user=417, product=1159, rating=4.920034668669241),
#    Rating(user=417, product=1269, rating=4.70721436754451),
#    Rating(user=417, product=613, rating=4.6796531864133195))),
#  (359,
#   (Rating(user=359, product=1643, rating=7.35597701379773),
#    Rating(user=359, product=361, rating=6.063432735572918),
#    Rating(user=359, product=1058, rating=5.535125065754524),
#    Rating(user=359, product=1159, rating=5.507234286671388),
#    Rating(user=359, product=1615, rating=5.437222375702907))),
#  (672,
#   (Rating(user=672, product=767, rating=8.686285174219716),
#    Rating(user=672, product=1255, rating=8.341814300698957),
#    Rating(user=672, product=1282, rating=8.22537684978686),
#    Rating(user=672, product=253, rating=7.627095381977266),
#    Rating(user=672, product=1174, rating=7.344509667827704))),
#  (685,
#   (Rating(user=685, product=1069, rating=7.400473205498551),
#    Rating(user=685, product=1242, rating=7.284068566690325),
#    Rating(user=685, product=958, rating=6.887922012919525),
#    Rating(user=685, product=904, rating=6.86292077286838),
#    Rating(user=685, product=1413, rating=6.797256032692202))),
#  (682,
#   (Rating(user=682, product=1159, rating=5.0724126199923285),
#    Rating(user=682, product=1368, rating=4.974133663806435),
#    Rating(user=682, product=884, rating=4.87577506896203),
#    Rating(user=682, product=1449, rating=4.703132968566653),
#    Rating(user=682, product=1643, rating=4.673944587587194))),
#  (152,
#   (Rating(user=152, product=1446, rating=7.83554013975739),
#    Rating(user=152, product=1242, rating=7.387018394632664),
#    Rating(user=152, product=1278, rating=6.5679626352621145),
#    Rating(user=152, product=905, rating=5.934454940993733),
#    Rating(user=152, product=1164, rating=5.900089683325586))),
#  (368,
#   (Rating(user=368, product=1313, rating=7.843992383365784),
#    Rating(user=368, product=884, rating=7.8262423213470145),
#    Rating(user=368, product=1286, rating=7.551185102636869),
#    Rating(user=368, product=593, rating=7.339430462046542),
#    Rating(user=368, product=1129, rating=7.29383021499971))),
#  (683,
#   (Rating(user=683, product=1643, rating=7.058880049315469),
#    Rating(user=683, product=613, rating=6.248638698226953),
#    Rating(user=683, product=848, rating=6.100658031778774),
#    Rating(user=683, product=1159, rating=6.092632710305393),
#    Rating(user=683, product=1449, rating=6.0278374497707885))),
#  (415,
#   (Rating(user=415, product=1114, rating=9.861990143122226),
#    Rating(user=415, product=962, rating=8.971779529726154),
#    Rating(user=415, product=1001, rating=8.591721761650685),
#    Rating(user=415, product=1065, rating=8.546253344340279),
#    Rating(user=415, product=1302, rating=8.367099472867356))),
#  (796,
#   (Rating(user=796, product=1141, rating=5.562121805612008),
#    Rating(user=796, product=1159, rating=5.470485197317004),
#    Rating(user=796, product=1483, rating=5.324613320368574),
#    Rating(user=796, product=966, rating=5.239081285595564),
#    Rating(user=796, product=22, rating=5.140257756105553))),
#  (791,
#   (Rating(user=791, product=1425, rating=10.428237805945757),
#    Rating(user=791, product=394, rating=10.175200697237901),
#    Rating(user=791, product=1598, rating=9.628464450567105),
#    Rating(user=791, product=776, rating=8.997558107962352),
#    Rating(user=791, product=630, rating=8.75842728268038))),
#  (236,
#   (Rating(user=236, product=1160, rating=10.505487928277631),
#    Rating(user=236, product=624, rating=7.749905009464357),
#    Rating(user=236, product=1207, rating=7.491514361856716),
#    Rating(user=236, product=867, rating=7.395522337084028),
#    Rating(user=236, product=464, rating=7.373442230557249))),
#  (74,
#   (Rating(user=74, product=624, rating=7.186916609213389),
#    Rating(user=74, product=915, rating=6.973463344059947),
#    Rating(user=74, product=1131, rating=6.742914789285301),
#    Rating(user=74, product=1615, rating=6.676614672033336),
#    Rating(user=74, product=1192, rating=6.474083256853836))),
#  (316,
#   (Rating(user=316, product=1160, rating=10.09911154764185),
#    Rating(user=316, product=1426, rating=9.849264564404141),
#    Rating(user=316, product=464, rating=9.054783505890843),
#    Rating(user=316, product=953, rating=8.85545317935214),
#    Rating(user=316, product=537, rating=8.81385158761652))),
#  (406,
#   (Rating(user=406, product=1368, rating=6.957832696730778),
#    Rating(user=406, product=884, rating=6.370505414418644),
#    Rating(user=406, product=1205, rating=6.361100759863032),
#    Rating(user=406, product=965, rating=5.743221914626711),
#    Rating(user=406, product=850, rating=5.689516261522693))),
#  (400,
#   (Rating(user=400, product=1022, rating=9.162031810226429),
#    Rating(user=400, product=1185, rating=8.4165498951986),
#    Rating(user=400, product=634, rating=8.254549431689895),
#    Rating(user=400, product=1643, rating=8.07878047917931),
#    Rating(user=400, product=1478, rating=7.907726050979001))),
#  (612,
#   (Rating(user=612, product=394, rating=9.025539190091786),
#    Rating(user=612, product=1426, rating=8.60970028159212),
#    Rating(user=612, product=1141, rating=7.643340822582873),
#    Rating(user=612, product=1120, rating=7.4682773839393),
#    Rating(user=612, product=1207, rating=6.994568755033034))),
#  (888,
#   (Rating(user=888, product=1314, rating=6.779808471692121),
#    Rating(user=888, product=775, rating=6.767358156653163),
#    Rating(user=888, product=497, rating=6.09732640304548),
#    Rating(user=888, product=753, rating=5.930695753104574),
#    Rating(user=888, product=467, rating=5.787306497614967))),
#  (103,
#   (Rating(user=103, product=904, rating=7.4411041383880825),
#    Rating(user=103, product=320, rating=7.436874288712902),
#    Rating(user=103, product=426, rating=7.412048068153314),
#    Rating(user=103, product=296, rating=7.314673953806663),
#    Rating(user=103, product=1129, rating=7.3045467291369395))),
#  (874,
#   (Rating(user=874, product=1643, rating=6.953918877195191),
#    Rating(user=874, product=361, rating=5.881719363003656),
#    Rating(user=874, product=1449, rating=5.361170118802003),
#    Rating(user=874, product=1463, rating=5.002667883598612),
#    Rating(user=874, product=136, rating=4.972284588792707))),
#  (588,
#   (Rating(user=588, product=394, rating=8.617189216391749),
#    Rating(user=588, product=1199, rating=7.192890053043806),
#    Rating(user=588, product=1169, rating=7.069846826414162),
#    Rating(user=588, product=1065, rating=6.951845835184665),
#    Rating(user=588, product=1075, rating=6.806010197013102))),
#  (764,
#   (Rating(user=764, product=1643, rating=5.784298920874851),
#    Rating(user=764, product=1141, rating=5.337830147831621),
#    Rating(user=764, product=1463, rating=5.313365961612326),
#    Rating(user=764, product=1169, rating=5.224646849573829),
#    Rating(user=764, product=394, rating=5.09159014369668))),
#  (269,
#   (Rating(user=269, product=1512, rating=7.075266315610442),
#    Rating(user=269, product=1266, rating=7.054901032963917),
#    Rating(user=269, product=390, rating=6.8005852435008585),
#    Rating(user=269, product=854, rating=6.670480907727509),
#    Rating(user=269, product=1298, rating=6.303132162635485))),
#  (334,
#   (Rating(user=334, product=1643, rating=5.690362792460804),
#    Rating(user=334, product=1159, rating=5.636152004859998),
#    Rating(user=334, product=1449, rating=5.197880709150564),
#    Rating(user=334, product=1099, rating=5.182890598698433),
#    Rating(user=334, product=884, rating=4.996475164853452))),
#  (162,
#   (Rating(user=162, product=394, rating=6.452412997346966),
#    Rating(user=162, product=1169, rating=6.274707870494785),
#    Rating(user=162, product=1268, rating=6.06003992706869),
#    Rating(user=162, product=836, rating=5.97333602325447),
#    Rating(user=162, product=1075, rating=5.901389752816101))),
#  (483,
#   (Rating(user=483, product=718, rating=6.943673858721077),
#    Rating(user=483, product=791, rating=6.1565188796913235),
#    Rating(user=483, product=916, rating=6.0778046790580955),
#    Rating(user=483, product=361, rating=6.05965018432817),
#    Rating(user=483, product=1153, rating=5.9908584533803655))),
#  (224,
#   (Rating(user=224, product=1141, rating=5.302309616129709),
#    Rating(user=224, product=1278, rating=5.2325563981629),
#    Rating(user=224, product=397, rating=5.2127576632247195),
#    Rating(user=224, product=1173, rating=5.180153392333934),
#    Rating(user=224, product=966, rating=5.067679655198613))),
#  (905,
#   (Rating(user=905, product=884, rating=6.54367707118896),
#    Rating(user=905, product=1463, rating=6.111759006892801),
#    Rating(user=905, product=1066, rating=6.085959657721449),
#    Rating(user=905, product=1069, rating=5.903829025482529),
#    Rating(user=905, product=836, rating=5.647651336565181))),
#  (120,
#   (Rating(user=120, product=1426, rating=7.616842075631526),
#    Rating(user=120, product=1438, rating=6.979406289286828),
#    Rating(user=120, product=1160, rating=6.260175050048535),
#    Rating(user=120, product=953, rating=6.223437747272526),
#    Rating(user=120, product=1594, rating=6.087332218933588))),
#  (890,
#   (Rating(user=890, product=1643, rating=7.42474945823775),
#    Rating(user=890, product=1463, rating=6.622436470991277),
#    Rating(user=890, product=1126, rating=6.455332048698437),
#    Rating(user=890, product=1553, rating=6.33620354593908),
#    Rating(user=890, product=361, rating=6.2942901081431195))),
#  (166,
# ...
#    Rating(user=85, product=1615, rating=4.673088786531965))),
#  (405,
#   (Rating(user=405, product=1164, rating=5.9507067994488665),
#    Rating(user=405, product=1185, rating=5.141376825842692),
#    Rating(user=405, product=534, rating=5.131978940016433),
#    Rating(user=405, product=263, rating=5.051072434493761),
#    Rating(user=405, product=1285, rating=4.881786201170502))),
#  (789,
#   (Rating(user=789, product=884, rating=9.893790897502866),
#    Rating(user=789, product=1205, rating=9.798725718728097),
#    Rating(user=789, product=1069, rating=9.558459424425267),
#    Rating(user=789, product=1066, rating=8.977609595611307),
#    Rating(user=789, product=1368, rating=8.595367710536783))),
#  (328,
#   (Rating(user=328, product=1643, rating=5.997939264979859),
#    Rating(user=328, product=909, rating=5.611124099507338),
#    Rating(user=328, product=1166, rating=5.339065177075156),
#    Rating(user=328, product=1141, rating=5.311085309781049),
#    Rating(user=328, product=904, rating=5.073865945912842))),
#  (225,
#   (Rating(user=225, product=1022, rating=8.183563399661159),
#    Rating(user=225, product=1643, rating=8.080355008577389),
#    Rating(user=225, product=868, rating=6.923416985069969),
#    Rating(user=225, product=1368, rating=6.751357101325685),
#    Rating(user=225, product=1615, rating=6.6208363085941))),
#  (706,
#   (Rating(user=706, product=776, rating=8.955348063896821),
#    Rating(user=706, product=1209, rating=7.742673614649668),
#    Rating(user=706, product=630, rating=7.407880259462114),
#    Rating(user=706, product=1058, rating=7.380330603595083),
#    Rating(user=706, product=1001, rating=7.189207126015287))),
#  (619,
#   (Rating(user=619, product=1483, rating=7.626893548168358),
#    Rating(user=619, product=1185, rating=7.625713617983454),
#    Rating(user=619, product=1438, rating=7.207134408133117),
#    Rating(user=619, product=534, rating=7.088369526897376),
#    Rating(user=619, product=574, rating=7.057140949107918))),
#  (230,
#   (Rating(user=230, product=1160, rating=7.631284756332764),
#    Rating(user=230, product=1242, rating=7.078046181647694),
#    Rating(user=230, product=1426, rating=6.64137378358144),
#    Rating(user=230, product=904, rating=6.561678518983687),
#    Rating(user=230, product=557, rating=6.547005921084097))),
#  (800,
#   (Rating(user=800, product=850, rating=6.213191661226755),
#    Rating(user=800, product=884, rating=6.196338956685276),
#    Rating(user=800, product=1137, rating=6.107442057374929),
#    Rating(user=800, product=353, rating=5.874896893967648),
#    Rating(user=800, product=1205, rating=5.8657408402827675))),
#  (570,
#   (Rating(user=570, product=791, rating=10.245192731429462),
#    Rating(user=570, product=1314, rating=8.914886353279968),
#    Rating(user=570, product=1071, rating=8.431507320982728),
#    Rating(user=570, product=1185, rating=8.426094637946179),
#    Rating(user=570, product=716, rating=8.41454129000736))),
#  (325,
#   (Rating(user=325, product=1643, rating=7.259732143068644),
#    Rating(user=325, product=361, rating=7.033958227007504),
#    Rating(user=325, product=718, rating=6.560885458568712),
#    Rating(user=325, product=793, rating=6.287803822678545),
#    Rating(user=325, product=522, rating=5.49715652561985))),
#  (465,
#   (Rating(user=465, product=718, rating=4.7148596104587215),
#    Rating(user=465, product=1375, rating=4.5617565959345034),
#    Rating(user=465, product=884, rating=4.488275105334518),
#    Rating(user=465, product=1154, rating=4.4771598735894536),
#    Rating(user=465, product=1153, rating=4.462330732857804))),
#  (323,
#   (Rating(user=323, product=1643, rating=6.1193673320455595),
#    Rating(user=323, product=1142, rating=5.671203064840557),
#    Rating(user=323, product=884, rating=5.560685211060674),
#    Rating(user=323, product=1449, rating=5.456626983846344),
#    Rating(user=323, product=1463, rating=5.435707231473255))),
#  (407,
#   (Rating(user=407, product=1643, rating=5.3517079853969),
#    Rating(user=407, product=1449, rating=5.16650747914839),
#    Rating(user=407, product=884, rating=5.049890713209241),
#    Rating(user=407, product=1463, rating=4.845196242755974),
#    Rating(user=407, product=1368, rating=4.829600094324174))),
#  (55,
#   (Rating(user=55, product=1022, rating=13.687808783673413),
#    Rating(user=55, product=1185, rating=12.179820775899897),
#    Rating(user=55, product=1411, rating=11.879039300715204),
#    Rating(user=55, product=1615, rating=11.789467001432616),
#    Rating(user=55, product=1128, rating=11.343965075703954))),
#  (802,
#   (Rating(user=802, product=1286, rating=6.274409641156981),
#    Rating(user=802, product=1038, rating=6.171230250553037),
#    Rating(user=802, product=1368, rating=6.155329136683298),
#    Rating(user=802, product=555, rating=5.845866815208694),
#    Rating(user=802, product=1019, rating=5.547524062959417))),
#  (927,
#   (Rating(user=927, product=1001, rating=9.526521850914072),
#    Rating(user=927, product=394, rating=8.650496484442254),
#    Rating(user=927, product=115, rating=7.458822294648607),
#    Rating(user=927, product=630, rating=7.177280667731215),
#    Rating(user=927, product=721, rating=7.159084478588692))),
#  (648,
#   (Rating(user=648, product=1286, rating=7.9821655529825115),
#    Rating(user=648, product=793, rating=5.840204788646243),
#    Rating(user=648, product=999, rating=5.754575184637606),
#    Rating(user=648, product=1142, rating=5.704545634529818),
#    Rating(user=648, product=50, rating=5.451895932059315))),
#  (107,
#   (Rating(user=107, product=1368, rating=9.033137186516798),
#    Rating(user=107, product=1266, rating=8.031946073662379),
#    Rating(user=107, product=1097, rating=7.8765902373928345),
#    Rating(user=107, product=1174, rating=7.829042284490306),
#    Rating(user=107, product=1205, rating=7.642535742873303))),
#  (610,
#   (Rating(user=610, product=1643, rating=6.1837661815922225),
#    Rating(user=610, product=1463, rating=5.598443539773276),
#    Rating(user=610, product=1141, rating=5.49444290747001),
#    Rating(user=610, product=1438, rating=5.471742644619008),
#    Rating(user=610, product=954, rating=5.177042162006777))),
#  (765,
#   (Rating(user=765, product=1211, rating=7.7952465279526155),
#    Rating(user=765, product=1512, rating=7.6302298667290955),
#    Rating(user=765, product=6, rating=7.4993623701307826),
#    Rating(user=765, product=695, rating=7.300354459905163),
#    Rating(user=765, product=512, rating=7.209221615264049))),
#  (792,
#   (Rating(user=792, product=1643, rating=5.970781757091122),
#    Rating(user=792, product=1449, rating=5.566610768993094),
#    Rating(user=792, product=320, rating=5.4101567363574645),
#    Rating(user=792, product=296, rating=5.05969906544089),
#    Rating(user=792, product=634, rating=4.969159167020471))),
#  (50,
#   (Rating(user=50, product=1181, rating=10.793909525665452),
#    Rating(user=50, product=695, rating=10.571129510491552),
#    Rating(user=50, product=320, rating=9.337925417371883),
#    Rating(user=50, product=1380, rating=9.126613660370761),
#    Rating(user=50, product=906, rating=9.066742599883405))),
#  (179,
#   (Rating(user=179, product=1336, rating=7.517109249993526),
#    Rating(user=179, product=698, rating=6.941482457772496),
#    Rating(user=179, product=817, rating=6.9355586550972195),
#    Rating(user=179, product=904, rating=6.658134712299959),
#    Rating(user=179, product=557, rating=6.625119697190131))),
#  (133,
#   (Rating(user=133, product=1154, rating=7.771557353357182),
#    Rating(user=133, product=1120, rating=6.538834764181878),
#    Rating(user=133, product=580, rating=6.389124165610554),
#    Rating(user=133, product=718, rating=6.176315823785731),
#    Rating(user=133, product=1347, rating=6.164343530748072))),
#  (205,
#   (Rating(user=205, product=989, rating=6.588504815047296),
#    Rating(user=205, product=1311, rating=6.275491003957168),
#    Rating(user=205, product=1282, rating=6.216143848881792),
#    Rating(user=205, product=1242, rating=6.165618230991427),
#    Rating(user=205, product=1639, rating=6.045443219667883))),
#  (154,
#   (Rating(user=154, product=1643, rating=7.823892505200012),
#    Rating(user=154, product=1368, rating=6.968939205626299),
#    Rating(user=154, product=1022, rating=6.223987089839042),
#    Rating(user=154, product=320, rating=6.021708615598941),
#    Rating(user=154, product=793, rating=5.764832227896321))),
#  (416,
#   (Rating(user=416, product=1643, rating=5.8620010251981105),
#    Rating(user=416, product=64, rating=5.520837906622314),
#    Rating(user=416, product=318, rating=5.473156910434171),
#    Rating(user=416, product=467, rating=5.390613446132257),
#    Rating(user=416, product=953, rating=5.389181656898663))),
#  (680,
#   (Rating(user=680, product=1302, rating=7.443064742876906),
#    Rating(user=680, product=1114, rating=7.322731953432385),
#    Rating(user=680, product=916, rating=7.162906489770648),
#    Rating(user=680, product=1184, rating=6.761366361133118),
#    Rating(user=680, product=426, rating=6.432880879963256))),
#  (873,
#   (Rating(user=873, product=1286, rating=10.831628202357042),
#    Rating(user=873, product=1503, rating=8.508128586159488),
#    Rating(user=873, product=1242, rating=8.328931902934283),
#    Rating(user=873, product=1154, rating=7.47677820932312),
#    Rating(user=873, product=1410, rating=7.369269725987222))),
#  (183,
#   (Rating(user=183, product=1167, rating=6.4809220024375644),
#    Rating(user=183, product=1192, rating=6.477591829305831),
#    Rating(user=183, product=536, rating=5.9943936987165065),
#    Rating(user=183, product=587, rating=5.589417422095751),
#    Rating(user=183, product=1438, rating=5.530905522832965))),
#  (422,
#   (Rating(user=422, product=1643, rating=6.179445863432849),
#    Rating(user=422, product=960, rating=5.629388175260829),
#    Rating(user=422, product=1005, rating=5.566257009662018),
#    Rating(user=422, product=906, rating=5.4569211251465095),
#    Rating(user=422, product=1449, rating=5.402011367449344))),
#  (596,
#   (Rating(user=596, product=1242, rating=7.6897641560132195),
#    Rating(user=596, product=904, rating=7.3053135654507875),
#    Rating(user=596, product=555, rating=7.143730957777247),
#    Rating(user=596, product=624, rating=7.127506706760594),
#    Rating(user=596, product=1503, rating=6.904764144405298))),
#  (788,
#   (Rating(user=788, product=909, rating=5.879468167921493),
#    Rating(user=788, product=1643, rating=5.5987085873990425),
#    Rating(user=788, product=867, rating=5.54872642005693),
#    Rating(user=788, product=1141, rating=5.391888208703347),
#    Rating(user=788, product=904, rating=5.227193522967514))),
#  (564,
#   (Rating(user=564, product=1160, rating=6.53226582863098),
#    Rating(user=564, product=1643, rating=6.098234941799722),
#    Rating(user=564, product=867, rating=5.529137647786308),
#    Rating(user=564, product=592, rating=5.492238828365526),
#    Rating(user=564, product=624, rating=5.445677557651808))),
#  (687,
#   (Rating(user=687, product=1643, rating=7.60160056630816),
#    Rating(user=687, product=1463, rating=6.83167597055789),
#    Rating(user=687, product=1449, rating=6.355744390033518),
#    Rating(user=687, product=634, rating=5.987150980553775),
#    Rating(user=687, product=50, rating=5.961632977104429))),
#  (47,
#   (Rating(user=47, product=718, rating=6.528686373957496),
#    Rating(user=47, product=361, rating=6.503068616156215),
#    Rating(user=47, product=1154, rating=6.377043258793864),
#    Rating(user=47, product=1174, rating=5.884756002583755),
#    Rating(user=47, product=1524, rating=5.645052880097209))),
#  (724,
#   (Rating(user=724, product=394, rating=6.365720014420569),
#    Rating(user=724, product=1075, rating=5.657019091694749),
#    Rating(user=724, product=1169, rating=5.5440903761657685),
#    Rating(user=724, product=1199, rating=5.450872879092235),
#    Rating(user=724, product=686, rating=5.353027468017245))),
#  (485,
#   (Rating(user=485, product=1154, rating=7.542936160606793),
#    Rating(user=485, product=1142, rating=7.115221541101491),
#    Rating(user=485, product=884, rating=6.958903985364492),
#    Rating(user=485, product=1286, rating=6.944338249261055),
#    Rating(user=485, product=1097, rating=6.87525549675642))),
#  (276,
#   (Rating(user=276, product=1643, rating=6.215043765879772),
#    Rating(user=276, product=1368, rating=6.084570495372308),
#    Rating(user=276, product=1449, rating=5.728238391896817),
#    Rating(user=276, product=884, rating=5.38848214367531),
#    Rating(user=276, product=793, rating=5.31995787544207))),
#  (374,
#   (Rating(user=374, product=1643, rating=6.23362980821506),
#    Rating(user=374, product=1446, rating=5.801792027612732),
#    Rating(user=374, product=534, rating=5.660180407928395),
#    Rating(user=374, product=1058, rating=5.619812920925106),
#    Rating(user=374, product=936, rating=5.438689054023927))),
#  (207,
#   (Rating(user=207, product=1643, rating=4.992922707996909),
#    Rating(user=207, product=1160, rating=4.675252042006429),
#    Rating(user=207, product=963, rating=4.490092303594578),
#    Rating(user=207, product=1446, rating=4.461368302912186),
#    Rating(user=207, product=1242, rating=4.452104984356106))),
#  (521,
#   (Rating(user=521, product=1449, rating=4.626084188567889),
#    Rating(user=521, product=1643, rating=4.512479781776909),
#    Rating(user=521, product=1159, rating=4.488408807475354),
#    Rating(user=521, product=613, rating=4.316561621978698),
#    Rating(user=521, product=1001, rating=4.3090603960221046))),
#  (739,
#   (Rating(user=739, product=1205, rating=12.874738865879197),
#    Rating(user=739, product=909, rating=12.605099533964346),
#    Rating(user=739, product=767, rating=12.284284715885118),
#    Rating(user=739, product=1166, rating=11.900510654997552),
#    Rating(user=739, product=1438, rating=11.693621491345663))),
#  (233,
#   (Rating(user=233, product=1160, rating=7.713013978494885),
#    Rating(user=233, product=624, rating=7.633661559967787),
#    Rating(user=233, product=904, rating=6.689584527092988),
#    Rating(user=233, product=1131, rating=6.674422229876234),
#    Rating(user=233, product=867, rating=6.468040772763054))),
#  (537,
#   (Rating(user=537, product=1643, rating=6.11491553483285),
#    Rating(user=537, product=361, rating=5.060002432395977),
#    Rating(user=537, product=1512, rating=4.4813772872630935),
#    Rating(user=537, product=1024, rating=4.3708948781720345),
#    Rating(user=537, product=1558, rating=4.30563713199671))),
#  (880,
#   (Rating(user=880, product=1368, rating=6.484089045718802),
#    Rating(user=880, product=1643, rating=5.621990199574246),
#    Rating(user=880, product=913, rating=5.436042034967485),
#    Rating(user=880, product=1062, rating=5.4075192242900405),
#    Rating(user=880, product=1176, rating=5.377512982151636))),
#  (604,
#   (Rating(user=604, product=916, rating=11.430277884170835),
#    Rating(user=604, product=1192, rating=11.391789135520487),
#    Rating(user=604, product=989, rating=11.027035637541772),
#    Rating(user=604, product=915, rating=10.921519808571121),
#    Rating(user=604, product=1639, rating=10.87148701914825))),
#  (377,
#   (Rating(user=377, product=1643, rating=6.72927724017501),
#    Rating(user=377, product=1286, rating=6.20201422492799),
#    Rating(user=377, product=1129, rating=6.1233801656425415),
#    Rating(user=377, product=1302, rating=5.958473846867451),
#    Rating(user=377, product=1113, rating=5.940419080708427))),
#  (384,
#   (Rating(user=384, product=1302, rating=5.7091236713495395),
#    Rating(user=384, product=296, rating=5.652288032187507),
#    Rating(user=384, product=1449, rating=5.6119163143539215),
#    Rating(user=384, product=962, rating=5.566844520826902),
#    Rating(user=384, product=1301, rating=5.54654296355664))),
#  (522,
#   (Rating(user=522, product=390, rating=9.012129272793658),
#    Rating(user=522, product=1643, rating=8.67719155174025),
#    Rating(user=522, product=1066, rating=8.045207776227212),
#    Rating(user=522, product=884, rating=8.015982421391657),
#    Rating(user=522, product=1463, rating=7.256588018075809))),
#  (315,
#   (Rating(user=315, product=960, rating=6.531754290716179),
#    Rating(user=315, product=537, rating=6.428958931350945),
#    Rating(user=315, product=1099, rating=6.385227308760738),
#    Rating(user=315, product=1512, rating=6.163728955804233),
#    Rating(user=315, product=1643, rating=6.1018381024081325)))]

# %%
df1=sqlContext.createDataFrame(p_movies)

# %%
df1.printSchema()
# Out:
# root
#  |-- _1: long (nullable = true)
#  |-- _2: struct (nullable = true)
#  |    |-- _1: struct (nullable = true)
#  |    |    |-- user: long (nullable = true)
#  |    |    |-- product: long (nullable = true)
#  |    |    |-- rating: double (nullable = true)
#  |    |-- _2: struct (nullable = true)
#  |    |    |-- user: long (nullable = true)
#  |    |    |-- product: long (nullable = true)
#  |    |    |-- rating: double (nullable = true)
#  |    |-- _3: struct (nullable = true)
#  |    |    |-- user: long (nullable = true)
#  |    |    |-- product: long (nullable = true)
#  |    |    |-- rating: double (nullable = true)
#  |    |-- _4: struct (nullable = true)
#  |    |    |-- user: long (nullable = true)
#  |    |    |-- product: long (nullable = true)
#  |    |    |-- rating: double (nullable = true)
#  |    |-- _5: struct (nullable = true)
#  |    |    |-- user: long (nullable = true)
#  |    |    |-- product: long (nullable = true)
#  |    |    |-- rating: double (nullable = true)
#  |    |-- _6: struct (nullable = true)
#  |    |    |-- user: long (nullable = true)
#  |    |    |-- product: long (nullable = true)
#  |    |    |-- rating: double (nullable = true)
#  |    |-- _7: struct (nullable = true)
#  |    |    |-- user: long (nullable = true)
#  |    |    |-- product: long (nullable = true)
#  |    |    |-- rating: double (nullable = true)
#  |    |-- _8: struct (nullable = true)
#  |    |    |-- user: long (nullable = true)
#  |    |    |-- product: long (nullable = true)
#  |    |    |-- rating: double (nullable = true)
#  |    |-- _9: struct (nullable = true)
#  |    |    |-- user: long (nullable = true)
#  |    |    |-- product: long (nullable = true)
#  |    |    |-- rating: double (nullable = true)
#  |    |-- _10: struct (nullable = true)
#  |    |    |-- user: long (nullable = true)
#  |    |    |-- product: long (nullable = true)
#  |    |    |-- rating: double (nullable = true)
